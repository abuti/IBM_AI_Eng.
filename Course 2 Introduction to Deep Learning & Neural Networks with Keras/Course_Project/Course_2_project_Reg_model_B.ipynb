# %% [markdown]
# # Regression Models with Keras

# %% [markdown]
# ### Instrucctions

# %% [markdown]
# A. Build a baseline model (5 marks)
#
# Use the Keras library to build a neural network with the following:
#
# - One hidden layer of 10 nodes, and a ReLU activation function
#
# - Use the adam optimizer and the mean squared error  as the loss function.
#
# 1. Randomly split the data into a training and test sets by holding 30% of the data for testing. You can use the
# train_test_split
# helper function from Scikit-learn.
#
# 2. Train the model on the training data using 50 epochs.
#
# 3. Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. You can use the mean_squared_error function from Scikit-learn.
#
# 4. Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.
#
# 5. Report the mean and the standard deviation of the mean squared errors.
#
# Submit your Jupyter Notebook with your code and comments.
#
# B. Normalize the data (5 marks)
#
# Repeat Part A but use a normalized version of the data. Recall that one way to normalize the data is by subtracting the mean from the individual predictors and dividing by the standard deviation.
#
# How does the mean of the mean squared errors compare to that from Step A?

# %% [markdown]
# ### Installing and importing

# %%
# installing scikit-learn if not installed
# !pip show scikit-learn

# %%
# importing all the libraries needed
import pandas as pd
import numpy as np
import sklearn

# %% [markdown]
# ## Let's download the data and read it into a pandas dataframe.

# %%
concrete_data = pd.read_csv('/content/drive/MyDrive/IBM_AI_Engineering_Professional_Certificate/Course 2 Introduction to Deep Learning & Neural Networks with Keras/Course_Project/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# ## 1. Randomly split the data into a training and test sets by holding 30% of the data for testing. You can use the train_test_split helper function from Scikit-learn.

# %% [markdown]
# ***Split data into training and test sets***

# %%
import sklearn.model_selection
from sklearn.model_selection import train_test_split
def split_train_test(concrete_data):
  train_data, test_data = train_test_split(concrete_data, test_size=0.3, train_size=0.7, random_state=42, shuffle=True, stratify=None)
  # print(f"Training dataset is 70% = {train_data.shape}")
  # print(f"Training dataset is 30% = {test_data.shape}")
  return train_data, test_data

# %% [markdown]
# ***Split data into predictors and target***

# %% [markdown]
# The target variable in this problem is the concrete sample strength and the predictors are all the other columns except age.

# %%
concrete_data_columns = concrete_data.columns
def split_pred_target(train_data, test_data):
  predictors_train  = train_data[concrete_data_columns[(concrete_data_columns != 'Strength') & (concrete_data_columns != 'Age')]] # all columns except Strength and Age
  target_train = train_data['Strength'] # Strength column
  # predictors_train.head()
  # target_train.head()
  predictors_test = test_data[concrete_data_columns[(concrete_data_columns != 'Strength') & (concrete_data_columns != 'Age')]] # all columns except Strength and Age
  target_test = test_data['Strength'] # Strength column
  # predictors_test.head()
  # target_test.head()
  return (predictors_train, target_train, predictors_test, target_test )

# %% [markdown]
# ***Normalize the data***

# %%
def normalize(x):
  x_norm = (x - x.mean()) / x.std()
  return x_norm


def normalize_data(predictors_train, target_train, predictors_test, target_test):
  predictors_train_norm = normalize(predictors_train)
  # predictors_train_norm.head()
  target_train_norm = normalize(target_train)
  # target_train_norm.head()
  predictors_test_norm = normalize(predictors_test)
  # predictors_test_norm.head()
  target_test_norm = normalize(target_test)
  # target_test_norm.head()
  return (predictors_train_norm, target_train_norm, predictors_test_norm, target_test_norm)

# %%
n_cols = 7
# print(n_cols)

# %% [markdown]
# ## 2. Train the model on the training data using 50 epochs.
# ## 3. Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. You can use the mean_squared_error function from Scikit-learn.

# %% [markdown]
# ***Build a Neural Network***

# %% [markdown]
# Import Keras and important modules

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# Define regression model

# %%
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(n_cols,)))  # since it has seven(7) predictors
    model.add(Dense(1))

    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# build the model
model = regression_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                80
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 91 (364.00 Byte)
# Trainable params: 91 (364.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 4. Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.

# %%
from sklearn.metrics import mean_squared_error
mse = []

for i in range(50):
  train_data, test_data = split_train_test(concrete_data)

  predictors_train, target_train, predictors_test, target_test = split_pred_target(train_data, test_data)

  predictors_train_norm, target_train_norm, predictors_test_norm, target_test_norm = normalize_data(predictors_train, target_train, predictors_test, target_test)

  # fit the model
  model.fit(predictors_train_norm, target_train_norm, validation_split=0.3, epochs=50, verbose=2)
  prediction_test = model.predict(predictors_test_norm, batch_size=None, verbose="auto", steps=None, callbacks=None)

  mse.append(mean_squared_error(target_test_norm, prediction_test))
# Out:
# Streaming output truncated to the last 5000 lines.
# 16/16 - 0s - loss: 0.5281 - val_loss: 0.5782 - 65ms/epoch - 4ms/step
# Epoch 27/50
# 16/16 - 0s - loss: 0.5239 - val_loss: 0.5776 - 64ms/epoch - 4ms/step
# Epoch 28/50
# 16/16 - 0s - loss: 0.5200 - val_loss: 0.5759 - 72ms/epoch - 4ms/step
# Epoch 29/50
# 16/16 - 0s - loss: 0.5171 - val_loss: 0.5726 - 71ms/epoch - 4ms/step
# Epoch 30/50
# 16/16 - 0s - loss: 0.5140 - val_loss: 0.5721 - 68ms/epoch - 4ms/step
# Epoch 31/50
# 16/16 - 0s - loss: 0.5098 - val_loss: 0.5705 - 75ms/epoch - 5ms/step
# Epoch 32/50
# 16/16 - 0s - loss: 0.5073 - val_loss: 0.5673 - 77ms/epoch - 5ms/step
# Epoch 33/50
# 16/16 - 0s - loss: 0.5041 - val_loss: 0.5663 - 67ms/epoch - 4ms/step
# Epoch 34/50
# 16/16 - 0s - loss: 0.5012 - val_loss: 0.5629 - 81ms/epoch - 5ms/step
# Epoch 35/50
# 16/16 - 0s - loss: 0.4990 - val_loss: 0.5621 - 64ms/epoch - 4ms/step
# Epoch 36/50
# 16/16 - 0s - loss: 0.4958 - val_loss: 0.5603 - 64ms/epoch - 4ms/step
# Epoch 37/50
# 16/16 - 0s - loss: 0.4930 - val_loss: 0.5562 - 70ms/epoch - 4ms/step
# Epoch 38/50
# 16/16 - 0s - loss: 0.4904 - val_loss: 0.5560 - 76ms/epoch - 5ms/step
# Epoch 39/50
# 16/16 - 0s - loss: 0.4881 - val_loss: 0.5540 - 66ms/epoch - 4ms/step
# Epoch 40/50
# 16/16 - 0s - loss: 0.4853 - val_loss: 0.5517 - 64ms/epoch - 4ms/step
# Epoch 41/50
# 16/16 - 0s - loss: 0.4842 - val_loss: 0.5496 - 65ms/epoch - 4ms/step
# Epoch 42/50
# 16/16 - 0s - loss: 0.4813 - val_loss: 0.5503 - 74ms/epoch - 5ms/step
# Epoch 43/50
# 16/16 - 0s - loss: 0.4791 - val_loss: 0.5480 - 70ms/epoch - 4ms/step
# Epoch 44/50
# 16/16 - 0s - loss: 0.4772 - val_loss: 0.5459 - 74ms/epoch - 5ms/step
# Epoch 45/50
# 16/16 - 0s - loss: 0.4754 - val_loss: 0.5474 - 64ms/epoch - 4ms/step
# Epoch 46/50
# 16/16 - 0s - loss: 0.4741 - val_loss: 0.5456 - 71ms/epoch - 4ms/step
# Epoch 47/50
# 16/16 - 0s - loss: 0.4723 - val_loss: 0.5467 - 74ms/epoch - 5ms/step
# Epoch 48/50
# 16/16 - 0s - loss: 0.4702 - val_loss: 0.5424 - 78ms/epoch - 5ms/step
# Epoch 49/50
# 16/16 - 0s - loss: 0.4695 - val_loss: 0.5409 - 64ms/epoch - 4ms/step
# Epoch 50/50
# 16/16 - 0s - loss: 0.4680 - val_loss: 0.5420 - 75ms/epoch - 5ms/step
# 10/10 [==============================] - 0s 3ms/step
# Epoch 1/50
# 16/16 - 0s - loss: 0.4661 - val_loss: 0.5411 - 335ms/epoch - 21ms/step
# Epoch 2/50
# 16/16 - 0s - loss: 0.4647 - val_loss: 0.5409 - 284ms/epoch - 18ms/step
# Epoch 3/50
# 16/16 - 0s - loss: 0.4637 - val_loss: 0.5405 - 302ms/epoch - 19ms/step
# Epoch 4/50
# 16/16 - 0s - loss: 0.4624 - val_loss: 0.5384 - 194ms/epoch - 12ms/step
# Epoch 5/50
# 16/16 - 0s - loss: 0.4612 - val_loss: 0.5372 - 154ms/epoch - 10ms/step
# Epoch 6/50
# 16/16 - 0s - loss: 0.4607 - val_loss: 0.5380 - 242ms/epoch - 15ms/step
# Epoch 7/50
# 16/16 - 0s - loss: 0.4609 - val_loss: 0.5341 - 190ms/epoch - 12ms/step
# Epoch 8/50
# 16/16 - 0s - loss: 0.4588 - val_loss: 0.5366 - 197ms/epoch - 12ms/step
# Epoch 9/50
# 16/16 - 0s - loss: 0.4579 - val_loss: 0.5368 - 164ms/epoch - 10ms/step
# Epoch 10/50
# 16/16 - 0s - loss: 0.4569 - val_loss: 0.5358 - 92ms/epoch - 6ms/step
# Epoch 11/50
# 16/16 - 0s - loss: 0.4559 - val_loss: 0.5325 - 96ms/epoch - 6ms/step
# Epoch 12/50
# 16/16 - 0s - loss: 0.4557 - val_loss: 0.5344 - 96ms/epoch - 6ms/step
# Epoch 13/50
# 16/16 - 0s - loss: 0.4551 - val_loss: 0.5320 - 100ms/epoch - 6ms/step
# Epoch 14/50
# 16/16 - 0s - loss: 0.4550 - val_loss: 0.5302 - 105ms/epoch - 7ms/step
# Epoch 15/50
# 16/16 - 0s - loss: 0.4540 - val_loss: 0.5330 - 102ms/epoch - 6ms/step
# Epoch 16/50
# 16/16 - 0s - loss: 0.4532 - val_loss: 0.5313 - 94ms/epoch - 6ms/step
# Epoch 17/50
# 16/16 - 0s - loss: 0.4523 - val_loss: 0.5307 - 99ms/epoch - 6ms/step
# Epoch 18/50
# 16/16 - 0s - loss: 0.4515 - val_loss: 0.5298 - 107ms/epoch - 7ms/step
# Epoch 19/50
# 16/16 - 0s - loss: 0.4515 - val_loss: 0.5318 - 100ms/epoch - 6ms/step
# Epoch 20/50
# 16/16 - 0s - loss: 0.4499 - val_loss: 0.5306 - 101ms/epoch - 6ms/step
# Epoch 21/50
# 16/16 - 0s - loss: 0.4502 - val_loss: 0.5293 - 97ms/epoch - 6ms/step
# Epoch 22/50
# 16/16 - 0s - loss: 0.4497 - val_loss: 0.5291 - 90ms/epoch - 6ms/step
# Epoch 23/50
# 16/16 - 0s - loss: 0.4483 - val_loss: 0.5304 - 94ms/epoch - 6ms/step
# Epoch 24/50
# 16/16 - 0s - loss: 0.4485 - val_loss: 0.5298 - 96ms/epoch - 6ms/step
# Epoch 25/50
# 16/16 - 0s - loss: 0.4486 - val_loss: 0.5287 - 101ms/epoch - 6ms/step
# Epoch 26/50
# 16/16 - 0s - loss: 0.4478 - val_loss: 0.5279 - 98ms/epoch - 6ms/step
# Epoch 27/50
# 16/16 - 0s - loss: 0.4468 - val_loss: 0.5283 - 99ms/epoch - 6ms/step
# Epoch 28/50
# 16/16 - 0s - loss: 0.4471 - val_loss: 0.5308 - 107ms/epoch - 7ms/step
# Epoch 29/50
# 16/16 - 0s - loss: 0.4471 - val_loss: 0.5269 - 93ms/epoch - 6ms/step
# Epoch 30/50
# 16/16 - 0s - loss: 0.4460 - val_loss: 0.5288 - 98ms/epoch - 6ms/step
# Epoch 31/50
# 16/16 - 0s - loss: 0.4457 - val_loss: 0.5279 - 101ms/epoch - 6ms/step
# Epoch 32/50
# 16/16 - 0s - loss: 0.4456 - val_loss: 0.5285 - 64ms/epoch - 4ms/step
# Epoch 33/50
# 16/16 - 0s - loss: 0.4445 - val_loss: 0.5272 - 69ms/epoch - 4ms/step
# Epoch 34/50
# 16/16 - 0s - loss: 0.4447 - val_loss: 0.5290 - 72ms/epoch - 4ms/step
# Epoch 35/50
# 16/16 - 0s - loss: 0.4442 - val_loss: 0.5290 - 66ms/epoch - 4ms/step
# Epoch 36/50
# 16/16 - 0s - loss: 0.4442 - val_loss: 0.5287 - 68ms/epoch - 4ms/step
# Epoch 37/50
# 16/16 - 0s - loss: 0.4436 - val_loss: 0.5265 - 98ms/epoch - 6ms/step
# Epoch 38/50
# 16/16 - 0s - loss: 0.4436 - val_loss: 0.5280 - 155ms/epoch - 10ms/step
# Epoch 39/50
# 16/16 - 0s - loss: 0.4434 - val_loss: 0.5265 - 127ms/epoch - 8ms/step
# Epoch 40/50
# 16/16 - 0s - loss: 0.4441 - val_loss: 0.5298 - 105ms/epoch - 7ms/step
# Epoch 41/50
# 16/16 - 0s - loss: 0.4447 - val_loss: 0.5254 - 104ms/epoch - 7ms/step
# Epoch 42/50
# 16/16 - 0s - loss: 0.4421 - val_loss: 0.5272 - 124ms/epoch - 8ms/step
# Epoch 43/50
# 16/16 - 0s - loss: 0.4422 - val_loss: 0.5284 - 69ms/epoch - 4ms/step
# Epoch 44/50
# 16/16 - 0s - loss: 0.4417 - val_loss: 0.5284 - 67ms/epoch - 4ms/step
# Epoch 45/50
# 16/16 - 0s - loss: 0.4438 - val_loss: 0.5261 - 75ms/epoch - 5ms/step
# Epoch 46/50
# 16/16 - 0s - loss: 0.4411 - val_loss: 0.5296 - 71ms/epoch - 4ms/step
# Epoch 47/50
# 16/16 - 0s - loss: 0.4418 - val_loss: 0.5283 - 65ms/epoch - 4ms/step
# Epoch 48/50
# 16/16 - 0s - loss: 0.4413 - val_loss: 0.5263 - 67ms/epoch - 4ms/step
# Epoch 49/50
# 16/16 - 0s - loss: 0.4410 - val_loss: 0.5295 - 69ms/epoch - 4ms/step
# Epoch 50/50
# 16/16 - 0s - loss: 0.4408 - val_loss: 0.5284 - 72ms/epoch - 4ms/step
# 10/10 [==============================] - 0s 2ms/step
# Epoch 1/50
# 16/16 - 0s - loss: 0.4406 - val_loss: 0.5256 - 112ms/epoch - 7ms/step
# Epoch 2/50
# 16/16 - 0s - loss: 0.4404 - val_loss: 0.5254 - 67ms/epoch - 4ms/step
# Epoch 3/50
# 16/16 - 0s - loss: 0.4402 - val_loss: 0.5256 - 68ms/epoch - 4ms/step
# Epoch 4/50
# 16/16 - 0s - loss: 0.4393 - val_loss: 0.5274 - 81ms/epoch - 5ms/step
# Epoch 5/50
# 16/16 - 0s - loss: 0.4396 - val_loss: 0.5281 - 80ms/epoch - 5ms/step
# Epoch 6/50
# 16/16 - 0s - loss: 0.4392 - val_loss: 0.5263 - 81ms/epoch - 5ms/step
# Epoch 7/50
# 16/16 - 0s - loss: 0.4392 - val_loss: 0.5268 - 73ms/epoch - 5ms/step
# Epoch 8/50
# 16/16 - 0s - loss: 0.4385 - val_loss: 0.5283 - 82ms/epoch - 5ms/step
# Epoch 9/50
# 16/16 - 0s - loss: 0.4385 - val_loss: 0.5263 - 70ms/epoch - 4ms/step
# Epoch 10/50
# 16/16 - 0s - loss: 0.4380 - val_loss: 0.5262 - 82ms/epoch - 5ms/step
# Epoch 11/50
# 16/16 - 0s - loss: 0.4381 - val_loss: 0.5280 - 79ms/epoch - 5ms/step
# Epoch 12/50
# 16/16 - 0s - loss: 0.4384 - val_loss: 0.5279 - 69ms/epoch - 4ms/step
# Epoch 13/50
# 16/16 - 0s - loss: 0.4385 - val_loss: 0.5272 - 71ms/epoch - 4ms/step
# Epoch 14/50
# 16/16 - 0s - loss: 0.4380 - val_loss: 0.5284 - 77ms/epoch - 5ms/step
# Epoch 15/50
# 16/16 - 0s - loss: 0.4372 - val_loss: 0.5265 - 76ms/epoch - 5ms/step
# Epoch 16/50
# 16/16 - 0s - loss: 0.4372 - val_loss: 0.5285 - 79ms/epoch - 5ms/step
# Epoch 17/50
# 16/16 - 0s - loss: 0.4378 - val_loss: 0.5290 - 70ms/epoch - 4ms/step
# Epoch 18/50
# 16/16 - 0s - loss: 0.4364 - val_loss: 0.5276 - 69ms/epoch - 4ms/step
# Epoch 19/50
# 16/16 - 0s - loss: 0.4359 - val_loss: 0.5266 - 70ms/epoch - 4ms/step
# Epoch 20/50
# 16/16 - 0s - loss: 0.4364 - val_loss: 0.5240 - 69ms/epoch - 4ms/step
# Epoch 21/50
# 16/16 - 0s - loss: 0.4355 - val_loss: 0.5262 - 67ms/epoch - 4ms/step
# Epoch 22/50
# 16/16 - 0s - loss: 0.4363 - val_loss: 0.5262 - 66ms/epoch - 4ms/step
# Epoch 23/50
# 16/16 - 0s - loss: 0.4360 - val_loss: 0.5266 - 135ms/epoch - 8ms/step
# Epoch 24/50
# 16/16 - 0s - loss: 0.4354 - val_loss: 0.5272 - 103ms/epoch - 6ms/step
# Epoch 25/50
# 16/16 - 0s - loss: 0.4351 - val_loss: 0.5267 - 102ms/epoch - 6ms/step
# Epoch 26/50
# 16/16 - 0s - loss: 0.4351 - val_loss: 0.5269 - 99ms/epoch - 6ms/step
# Epoch 27/50
# 16/16 - 0s - loss: 0.4351 - val_loss: 0.5264 - 96ms/epoch - 6ms/step
# Epoch 28/50
# 16/16 - 0s - loss: 0.4344 - val_loss: 0.5256 - 100ms/epoch - 6ms/step
# Epoch 29/50
# 16/16 - 0s - loss: 0.4342 - val_loss: 0.5255 - 94ms/epoch - 6ms/step
# Epoch 30/50
# 16/16 - 0s - loss: 0.4341 - val_loss: 0.5261 - 97ms/epoch - 6ms/step
# Epoch 31/50
# 16/16 - 0s - loss: 0.4345 - val_loss: 0.5265 - 97ms/epoch - 6ms/step
# Epoch 32/50
# 16/16 - 0s - loss: 0.4336 - val_loss: 0.5251 - 96ms/epoch - 6ms/step
# Epoch 33/50
# 16/16 - 0s - loss: 0.4338 - val_loss: 0.5279 - 97ms/epoch - 6ms/step
# Epoch 34/50
# 16/16 - 0s - loss: 0.4338 - val_loss: 0.5262 - 97ms/epoch - 6ms/step
# Epoch 35/50
# 16/16 - 0s - loss: 0.4331 - val_loss: 0.5268 - 95ms/epoch - 6ms/step
# Epoch 36/50
# 16/16 - 0s - loss: 0.4327 - val_loss: 0.5240 - 99ms/epoch - 6ms/step
# Epoch 37/50
# 16/16 - 0s - loss: 0.4331 - val_loss: 0.5255 - 106ms/epoch - 7ms/step
# Epoch 38/50
# 16/16 - 0s - loss: 0.4331 - val_loss: 0.5244 - 96ms/epoch - 6ms/step
# Epoch 39/50
# 16/16 - 0s - loss: 0.4327 - val_loss: 0.5257 - 96ms/epoch - 6ms/step
# Epoch 40/50
# 16/16 - 0s - loss: 0.4322 - val_loss: 0.5241 - 98ms/epoch - 6ms/step
# Epoch 41/50
# 16/16 - 0s - loss: 0.4321 - val_loss: 0.5250 - 95ms/epoch - 6ms/step
# Epoch 42/50
# 16/16 - 0s - loss: 0.4324 - val_loss: 0.5245 - 102ms/epoch - 6ms/step
# Epoch 43/50
# 16/16 - 0s - loss: 0.4324 - val_loss: 0.5269 - 104ms/epoch - 7ms/step
# Epoch 44/50
# 16/16 - 0s - loss: 0.4313 - val_loss: 0.5257 - 114ms/epoch - 7ms/step
# Epoch 45/50
# 16/16 - 0s - loss: 0.4323 - val_loss: 0.5245 - 142ms/epoch - 9ms/step
# Epoch 46/50
# 16/16 - 0s - loss: 0.4306 - val_loss: 0.5242 - 130ms/epoch - 8ms/step
# Epoch 47/50
# 16/16 - 0s - loss: 0.4330 - val_loss: 0.5262 - 108ms/epoch - 7ms/step
# Epoch 48/50
# 16/16 - 0s - loss: 0.4301 - val_loss: 0.5239 - 138ms/epoch - 9ms/step
# Epoch 49/50
# 16/16 - 0s - loss: 0.4310 - val_loss: 0.5260 - 160ms/epoch - 10ms/step
# Epoch 50/50
# 16/16 - 0s - loss: 0.4301 - val_loss: 0.5242 - 132ms/epoch - 8ms/step
# 10/10 [==============================] - 0s 4ms/step
# Epoch 1/50
# 16/16 - 0s - loss: 0.4303 - val_loss: 0.5240 - 231ms/epoch - 14ms/step
# Epoch 2/50
# 16/16 - 0s - loss: 0.4300 - val_loss: 0.5256 - 139ms/epoch - 9ms/step
# Epoch 3/50
# 16/16 - 0s - loss: 0.4300 - val_loss: 0.5234 - 130ms/epoch - 8ms/step
# Epoch 4/50
# 16/16 - 0s - loss: 0.4310 - val_loss: 0.5245 - 102ms/epoch - 6ms/step
# Epoch 5/50
# 16/16 - 0s - loss: 0.4288 - val_loss: 0.5238 - 154ms/epoch - 10ms/step
# Epoch 6/50
# 16/16 - 0s - loss: 0.4292 - val_loss: 0.5229 - 103ms/epoch - 6ms/step
# Epoch 7/50
# 16/16 - 0s - loss: 0.4295 - val_loss: 0.5258 - 121ms/epoch - 8ms/step
# Epoch 8/50
# 16/16 - 0s - loss: 0.4283 - val_loss: 0.5235 - 153ms/epoch - 10ms/step
# Epoch 9/50
# 16/16 - 0s - loss: 0.4292 - val_loss: 0.5242 - 146ms/epoch - 9ms/step
# Epoch 10/50
# 16/16 - 0s - loss: 0.4285 - val_loss: 0.5225 - 121ms/epoch - 8ms/step
# Epoch 11/50
# 16/16 - 0s - loss: 0.4286 - val_loss: 0.5237 - 125ms/epoch - 8ms/step
# Epoch 12/50
# 16/16 - 0s - loss: 0.4288 - val_loss: 0.5201 - 160ms/epoch - 10ms/step
# Epoch 13/50
# 16/16 - 0s - loss: 0.4285 - val_loss: 0.5220 - 160ms/epoch - 10ms/step
# Epoch 14/50
# 16/16 - 0s - loss: 0.4284 - val_loss: 0.5236 - 159ms/epoch - 10ms/step
# Epoch 15/50
# 16/16 - 0s - loss: 0.4284 - val_loss: 0.5245 - 168ms/epoch - 10ms/step
# Epoch 16/50
# 16/16 - 0s - loss: 0.4279 - val_loss: 0.5218 - 124ms/epoch - 8ms/step
# Epoch 17/50
# 16/16 - 0s - loss: 0.4279 - val_loss: 0.5208 - 116ms/epoch - 7ms/step
# Epoch 18/50
# 16/16 - 0s - loss: 0.4268 - val_loss: 0.5206 - 168ms/epoch - 10ms/step
# Epoch 19/50
# 16/16 - 0s - loss: 0.4271 - val_loss: 0.5224 - 109ms/epoch - 7ms/step
# Epoch 20/50
# 16/16 - 0s - loss: 0.4270 - val_loss: 0.5217 - 127ms/epoch - 8ms/step
# Epoch 21/50
# 16/16 - 0s - loss: 0.4271 - val_loss: 0.5235 - 97ms/epoch - 6ms/step
# Epoch 22/50
# 16/16 - 0s - loss: 0.4273 - val_loss: 0.5240 - 127ms/epoch - 8ms/step
# Epoch 23/50
# 16/16 - 0s - loss: 0.4273 - val_loss: 0.5225 - 105ms/epoch - 7ms/step
# Epoch 24/50
# 16/16 - 0s - loss: 0.4264 - val_loss: 0.5231 - 99ms/epoch - 6ms/step
# Epoch 25/50
# 16/16 - 0s - loss: 0.4262 - val_loss: 0.5216 - 111ms/epoch - 7ms/step
# Epoch 26/50
# 16/16 - 0s - loss: 0.4260 - val_loss: 0.5214 - 176ms/epoch - 11ms/step
# Epoch 27/50
# 16/16 - 0s - loss: 0.4258 - val_loss: 0.5223 - 106ms/epoch - 7ms/step
# Epoch 28/50
# 16/16 - 0s - loss: 0.4264 - val_loss: 0.5238 - 106ms/epoch - 7ms/step
# Epoch 29/50
# 16/16 - 0s - loss: 0.4252 - val_loss: 0.5218 - 99ms/epoch - 6ms/step
# Epoch 30/50
# 16/16 - 0s - loss: 0.4255 - val_loss: 0.5198 - 92ms/epoch - 6ms/step
# Epoch 31/50
# 16/16 - 0s - loss: 0.4260 - val_loss: 0.5211 - 101ms/epoch - 6ms/step
# Epoch 32/50
# 16/16 - 0s - loss: 0.4253 - val_loss: 0.5223 - 100ms/epoch - 6ms/step
# Epoch 33/50
# 16/16 - 0s - loss: 0.4253 - val_loss: 0.5217 - 96ms/epoch - 6ms/step
# Epoch 34/50
# 16/16 - 0s - loss: 0.4249 - val_loss: 0.5204 - 94ms/epoch - 6ms/step
# Epoch 35/50
# 16/16 - 0s - loss: 0.4253 - val_loss: 0.5222 - 94ms/epoch - 6ms/step
# Epoch 36/50
# 16/16 - 0s - loss: 0.4252 - val_loss: 0.5207 - 96ms/epoch - 6ms/step
# Epoch 37/50
# 16/16 - 0s - loss: 0.4252 - val_loss: 0.5206 - 139ms/epoch - 9ms/step
# Epoch 38/50
# 16/16 - 0s - loss: 0.4239 - val_loss: 0.5220 - 100ms/epoch - 6ms/step
# Epoch 39/50
# 16/16 - 0s - loss: 0.4254 - val_loss: 0.5210 - 94ms/epoch - 6ms/step
# Epoch 40/50
# 16/16 - 0s - loss: 0.4253 - val_loss: 0.5191 - 100ms/epoch - 6ms/step
# Epoch 41/50
# 16/16 - 0s - loss: 0.4248 - val_loss: 0.5229 - 115ms/epoch - 7ms/step
# Epoch 42/50
# 16/16 - 0s - loss: 0.4248 - val_loss: 0.5223 - 99ms/epoch - 6ms/step
# Epoch 43/50
# 16/16 - 0s - loss: 0.4246 - val_loss: 0.5194 - 101ms/epoch - 6ms/step
# Epoch 44/50
# 16/16 - 0s - loss: 0.4236 - val_loss: 0.5218 - 66ms/epoch - 4ms/step
# Epoch 45/50
# 16/16 - 0s - loss: 0.4239 - val_loss: 0.5233 - 73ms/epoch - 5ms/step
# Epoch 46/50
# 16/16 - 0s - loss: 0.4246 - val_loss: 0.5192 - 69ms/epoch - 4ms/step
# Epoch 47/50
# 16/16 - 0s - loss: 0.4238 - val_loss: 0.5218 - 74ms/epoch - 5ms/step
# Epoch 48/50
# 16/16 - 0s - loss: 0.4233 - val_loss: 0.5210 - 74ms/epoch - 5ms/step
# Epoch 49/50
# 16/16 - 0s - loss: 0.4236 - val_loss: 0.5223 - 63ms/epoch - 4ms/step
# Epoch 50/50
# 16/16 - 0s - loss: 0.4233 - val_loss: 0.5217 - 62ms/epoch - 4ms/step
# 10/10 [==============================] - 0s 2ms/step
# Epoch 1/50
# 16/16 - 0s - loss: 0.4235 - val_loss: 0.5195 - 106ms/epoch - 7ms/step
# Epoch 2/50
# 16/16 - 0s - loss: 0.4229 - val_loss: 0.5193 - 64ms/epoch - 4ms/step
# Epoch 3/50
# 16/16 - 0s - loss: 0.4225 - val_loss: 0.5188 - 73ms/epoch - 5ms/step
# Epoch 4/50
# 16/16 - 0s - loss: 0.4242 - val_loss: 0.5195 - 74ms/epoch - 5ms/step
# Epoch 5/50
# 16/16 - 0s - loss: 0.4220 - val_loss: 0.5200 - 76ms/epoch - 5ms/step
# Epoch 6/50
# 16/16 - 0s - loss: 0.4225 - val_loss: 0.5193 - 66ms/epoch - 4ms/step
# Epoch 7/50
# 16/16 - 0s - loss: 0.4223 - val_loss: 0.5188 - 65ms/epoch - 4ms/step
# Epoch 8/50
# 16/16 - 0s - loss: 0.4226 - val_loss: 0.5209 - 75ms/epoch - 5ms/step
# Epoch 9/50
# 16/16 - 0s - loss: 0.4226 - val_loss: 0.5187 - 76ms/epoch - 5ms/step
# Epoch 10/50
# 16/16 - 0s - loss: 0.4224 - val_loss: 0.5196 - 76ms/epoch - 5ms/step
# Epoch 11/50
# 16/16 - 0s - loss: 0.4220 - val_loss: 0.5198 - 83ms/epoch - 5ms/step
# Epoch 12/50
# 16/16 - 0s - loss: 0.4228 - val_loss: 0.5199 - 65ms/epoch - 4ms/step
# Epoch 13/50
# 16/16 - 0s - loss: 0.4226 - val_loss: 0.5184 - 69ms/epoch - 4ms/step
# Epoch 14/50
# 16/16 - 0s - loss: 0.4222 - val_loss: 0.5225 - 75ms/epoch - 5ms/step
# Epoch 15/50
# 16/16 - 0s - loss: 0.4214 - val_loss: 0.5203 - 74ms/epoch - 5ms/step
# Epoch 16/50
# 16/16 - 0s - loss: 0.4226 - val_loss: 0.5156 - 75ms/epoch - 5ms/step
# Epoch 17/50
# 16/16 - 0s - loss: 0.4220 - val_loss: 0.5205 - 67ms/epoch - 4ms/step
# Epoch 18/50
# 16/16 - 0s - loss: 0.4210 - val_loss: 0.5186 - 73ms/epoch - 5ms/step
# Epoch 19/50
# 16/16 - 0s - loss: 0.4205 - val_loss: 0.5181 - 75ms/epoch - 5ms/step
# Epoch 20/50
# 16/16 - 0s - loss: 0.4214 - val_loss: 0.5166 - 72ms/epoch - 5ms/step
# Epoch 21/50
# 16/16 - 0s - loss: 0.4208 - val_loss: 0.5186 - 75ms/epoch - 5ms/step
# Epoch 22/50
# 16/16 - 0s - loss: 0.4213 - val_loss: 0.5189 - 66ms/epoch - 4ms/step
# Epoch 23/50
# 16/16 - 0s - loss: 0.4218 - val_loss: 0.5196 - 72ms/epoch - 5ms/step
# Epoch 24/50
# 16/16 - 0s - loss: 0.4207 - val_loss: 0.5200 - 66ms/epoch - 4ms/step
# Epoch 25/50
# 16/16 - 0s - loss: 0.4208 - val_loss: 0.5175 - 84ms/epoch - 5ms/step
# Epoch 26/50
# 16/16 - 0s - loss: 0.4205 - val_loss: 0.5180 - 70ms/epoch - 4ms/step
# Epoch 27/50
# 16/16 - 0s - loss: 0.4206 - val_loss: 0.5187 - 75ms/epoch - 5ms/step
# Epoch 28/50
# 16/16 - 0s - loss: 0.4202 - val_loss: 0.5176 - 74ms/epoch - 5ms/step
# Epoch 29/50
# 16/16 - 0s - loss: 0.4200 - val_loss: 0.5188 - 68ms/epoch - 4ms/step
# Epoch 30/50
# 16/16 - 0s - loss: 0.4194 - val_loss: 0.5196 - 75ms/epoch - 5ms/step
# Epoch 31/50
# 16/16 - 0s - loss: 0.4203 - val_loss: 0.5190 - 74ms/epoch - 5ms/step
# Epoch 32/50
# 16/16 - 0s - loss: 0.4194 - val_loss: 0.5172 - 64ms/epoch - 4ms/step
# Epoch 33/50
# 16/16 - 0s - loss: 0.4193 - val_loss: 0.5181 - 69ms/epoch - 4ms/step
# Epoch 34/50
# 16/16 - 0s - loss: 0.4192 - val_loss: 0.5199 - 64ms/epoch - 4ms/step
# Epoch 35/50
# 16/16 - 0s - loss: 0.4194 - val_loss: 0.5210 - 64ms/epoch - 4ms/step
# Epoch 36/50
# 16/16 - 0s - loss: 0.4194 - val_loss: 0.5160 - 74ms/epoch - 5ms/step
# Epoch 37/50
# 16/16 - 0s - loss: 0.4187 - val_loss: 0.5189 - 68ms/epoch - 4ms/step
# Epoch 38/50
# 16/16 - 0s - loss: 0.4189 - val_loss: 0.5178 - 77ms/epoch - 5ms/step
# Epoch 39/50
# 16/16 - 0s - loss: 0.4191 - val_loss: 0.5185 - 87ms/epoch - 5ms/step
# Epoch 40/50
# 16/16 - 0s - loss: 0.4192 - val_loss: 0.5183 - 77ms/epoch - 5ms/step
# Epoch 41/50
# 16/16 - 0s - loss: 0.4185 - val_loss: 0.5192 - 64ms/epoch - 4ms/step
# Epoch 42/50
# 16/16 - 0s - loss: 0.4178 - val_loss: 0.5171 - 73ms/epoch - 5ms/step
# Epoch 43/50
# 16/16 - 0s - loss: 0.4196 - val_loss: 0.5172 - 69ms/epoch - 4ms/step
# Epoch 44/50
# 16/16 - 0s - loss: 0.4187 - val_loss: 0.5186 - 66ms/epoch - 4ms/step
# Epoch 45/50
# 16/16 - 0s - loss: 0.4180 - val_loss: 0.5191 - 77ms/epoch - 5ms/step
# Epoch 46/50
# 16/16 - 0s - loss: 0.4174 - val_loss: 0.5178 - 67ms/epoch - 4ms/step
# Epoch 47/50
# 16/16 - 0s - loss: 0.4180 - val_loss: 0.5189 - 72ms/epoch - 5ms/step
# Epoch 48/50
# 16/16 - 0s - loss: 0.4170 - val_loss: 0.5173 - 66ms/epoch - 4ms/step
# Epoch 49/50
# 16/16 - 0s - loss: 0.4170 - val_loss: 0.5171 - 67ms/epoch - 4ms/step
# Epoch 50/50
# 16/16 - 0s - loss: 0.4170 - val_loss: 0.5183 - 64ms/epoch - 4ms/step
# 10/10 [==============================] - 0s 2ms/step
# Epoch 1/50
# 16/16 - 0s - loss: 0.4168 - val_loss: 0.5157 - 137ms/epoch - 9ms/step
# Epoch 2/50
# 16/16 - 0s - loss: 0.4164 - val_loss: 0.5168 - 71ms/epoch - 4ms/step
# Epoch 3/50
# 16/16 - 0s - loss: 0.4176 - val_loss: 0.5199 - 73ms/epoch - 5ms/step
# Epoch 4/50
# 16/16 - 0s - loss: 0.4169 - val_loss: 0.5166 - 67ms/epoch - 4ms/step
# Epoch 5/50
# 16/16 - 0s - loss: 0.4162 - val_loss: 0.5163 - 66ms/epoch - 4ms/step
# Epoch 6/50
# 16/16 - 0s - loss: 0.4162 - val_loss: 0.5151 - 64ms/epoch - 4ms/step
# Epoch 7/50
# 16/16 - 0s - loss: 0.4162 - val_loss: 0.5193 - 63ms/epoch - 4ms/step
# Epoch 8/50
# 16/16 - 0s - loss: 0.4158 - val_loss: 0.5169 - 63ms/epoch - 4ms/step
# Epoch 9/50
# 16/16 - 0s - loss: 0.4161 - val_loss: 0.5151 - 78ms/epoch - 5ms/step
# Epoch 10/50
# 16/16 - 0s - loss: 0.4158 - val_loss: 0.5172 - 74ms/epoch - 5ms/step
# Epoch 11/50
# 16/16 - 0s - loss: 0.4155 - val_loss: 0.5167 - 65ms/epoch - 4ms/step
# Epoch 12/50
# 16/16 - 0s - loss: 0.4161 - val_loss: 0.5155 - 76ms/epoch - 5ms/step
# Epoch 13/50
# 16/16 - 0s - loss: 0.4154 - val_loss: 0.5179 - 68ms/epoch - 4ms/step
# Epoch 14/50
# 16/16 - 0s - loss: 0.4154 - val_loss: 0.5183 - 92ms/epoch - 6ms/step
# Epoch 15/50
# 16/16 - 0s - loss: 0.4162 - val_loss: 0.5147 - 107ms/epoch - 7ms/step
# Epoch 16/50
# 16/16 - 0s - loss: 0.4150 - val_loss: 0.5144 - 95ms/epoch - 6ms/step
# Epoch 17/50
# 16/16 - 0s - loss: 0.4147 - val_loss: 0.5156 - 97ms/epoch - 6ms/step
# Epoch 18/50
# 16/16 - 0s - loss: 0.4152 - val_loss: 0.5165 - 99ms/epoch - 6ms/step
# Epoch 19/50
# 16/16 - 0s - loss: 0.4162 - val_loss: 0.5164 - 93ms/epoch - 6ms/step
# Epoch 20/50
# 16/16 - 0s - loss: 0.4147 - val_loss: 0.5154 - 88ms/epoch - 6ms/step
# Epoch 21/50
# 16/16 - 0s - loss: 0.4143 - val_loss: 0.5149 - 97ms/epoch - 6ms/step
# Epoch 22/50
# 16/16 - 0s - loss: 0.4155 - val_loss: 0.5171 - 96ms/epoch - 6ms/step
# Epoch 23/50
# 16/16 - 0s - loss: 0.4143 - val_loss: 0.5151 - 94ms/epoch - 6ms/step
# Epoch 24/50
# 16/16 - 0s - loss: 0.4144 - val_loss: 0.5154 - 116ms/epoch - 7ms/step
# Epoch 25/50
# 16/16 - 0s - loss: 0.4139 - val_loss: 0.5147 - 91ms/epoch - 6ms/step
# Epoch 26/50
# 16/16 - 0s - loss: 0.4145 - val_loss: 0.5132 - 97ms/epoch - 6ms/step
# Epoch 27/50
# 16/16 - 0s - loss: 0.4139 - val_loss: 0.5158 - 103ms/epoch - 6ms/step
# Epoch 28/50
# 16/16 - 0s - loss: 0.4148 - val_loss: 0.5163 - 97ms/epoch - 6ms/step
# Epoch 29/50
# 16/16 - 0s - loss: 0.4148 - val_loss: 0.5174 - 100ms/epoch - 6ms/step
# Epoch 30/50
# 16/16 - 0s - loss: 0.4143 - val_loss: 0.5142 - 97ms/epoch - 6ms/step
# Epoch 31/50
# 16/16 - 0s - loss: 0.4146 - val_loss: 0.5161 - 110ms/epoch - 7ms/step
# Epoch 32/50
# 16/16 - 0s - loss: 0.4142 - val_loss: 0.5158 - 98ms/epoch - 6ms/step
# Epoch 33/50
# 16/16 - 0s - loss: 0.4137 - val_loss: 0.5145 - 93ms/epoch - 6ms/step
# Epoch 34/50
# 16/16 - 0s - loss: 0.4140 - val_loss: 0.5136 - 104ms/epoch - 6ms/step
# Epoch 35/50
# 16/16 - 0s - loss: 0.4139 - val_loss: 0.5171 - 89ms/epoch - 6ms/step
# Epoch 36/50
# 16/16 - 0s - loss: 0.4143 - val_loss: 0.5185 - 92ms/epoch - 6ms/step
# Epoch 37/50
# 16/16 - 0s - loss: 0.4136 - val_loss: 0.5142 - 102ms/epoch - 6ms/step
# Epoch 38/50
# 16/16 - 0s - loss: 0.4147 - val_loss: 0.5162 - 96ms/epoch - 6ms/step
# Epoch 39/50
# 16/16 - 0s - loss: 0.4135 - val_loss: 0.5155 - 97ms/epoch - 6ms/step
# Epoch 40/50
# 16/16 - 0s - loss: 0.4134 - val_loss: 0.5149 - 96ms/epoch - 6ms/step
# Epoch 41/50
# 16/16 - 0s - loss: 0.4138 - val_loss: 0.5135 - 101ms/epoch - 6ms/step
# Epoch 42/50
# 16/16 - 0s - loss: 0.4134 - val_loss: 0.5177 - 96ms/epoch - 6ms/step
# Epoch 43/50
# 16/16 - 0s - loss: 0.4147 - val_loss: 0.5139 - 111ms/epoch - 7ms/step
# Epoch 44/50
# 16/16 - 0s - loss: 0.4131 - val_loss: 0.5175 - 110ms/epoch - 7ms/step
# Epoch 45/50
# 16/16 - 0s - loss: 0.4145 - val_loss: 0.5158 - 96ms/epoch - 6ms/step
# Epoch 46/50
# 16/16 - 0s - loss: 0.4132 - val_loss: 0.5188 - 91ms/epoch - 6ms/step
# Epoch 47/50
# 16/16 - 0s - loss: 0.4138 - val_loss: 0.5175 - 91ms/epoch - 6ms/step
# Epoch 48/50
# 16/16 - 0s - loss: 0.4136 - val_loss: 0.5140 - 103ms/epoch - 6ms/step
# Epoch 49/50
# 16/16 - 0s - loss: 0.4132 - val_loss: 0.5153 - 92ms/epoch - 6ms/step
# Epoch 50/50
# 16/16 - 0s - loss: 0.4128 - val_loss: 0.5160 - 95ms/epoch - 6ms/step
# 10/10 [==============================] - 0s 3ms/step
# Epoch 1/50
# 16/16 - 0s - loss: 0.4128 - val_loss: 0.5174 - 168ms/epoch - 11ms/step
# Epoch 2/50
# 16/16 - 0s - loss: 0.4125 - val_loss: 0.5177 - 65ms/epoch - 4ms/step
# Epoch 3/50
# 16/16 - 0s - loss: 0.4130 - val_loss: 0.5168 - 74ms/epoch - 5ms/step
# Epoch 4/50
# 16/16 - 0s - loss: 0.4124 - val_loss: 0.5148 - 64ms/epoch - 4ms/step
# Epoch 5/50
# 16/16 - 0s - loss: 0.4131 - val_loss: 0.5155 - 66ms/epoch - 4ms/step
# Epoch 6/50
# 16/16 - 0s - loss: 0.4126 - val_loss: 0.5159 - 74ms/epoch - 5ms/step
# Epoch 7/50
# 16/16 - 0s - loss: 0.4129 - val_loss: 0.5158 - 77ms/epoch - 5ms/step
# Epoch 8/50
# 16/16 - 0s - loss: 0.4128 - val_loss: 0.5154 - 69ms/epoch - 4ms/step
# Epoch 9/50
# 16/16 - 0s - loss: 0.4127 - val_loss: 0.5148 - 68ms/epoch - 4ms/step
# Epoch 10/50
# 16/16 - 0s - loss: 0.4127 - val_loss: 0.5145 - 67ms/epoch - 4ms/step
# Epoch 11/50
# 16/16 - 0s - loss: 0.4122 - val_loss: 0.5151 - 75ms/epoch - 5ms/step
# Epoch 12/50
# 16/16 - 0s - loss: 0.4135 - val_loss: 0.5184 - 73ms/epoch - 5ms/step
# Epoch 13/50
# 16/16 - 0s - loss: 0.4119 - val_loss: 0.5166 - 75ms/epoch - 5ms/step
# Epoch 14/50
# 16/16 - 0s - loss: 0.4124 - val_loss: 0.5137 - 76ms/epoch - 5ms/step
# Epoch 15/50
# 16/16 - 0s - loss: 0.4121 - val_loss: 0.5173 - 67ms/epoch - 4ms/step
# Epoch 16/50
# 16/16 - 0s - loss: 0.4124 - val_loss: 0.5183 - 76ms/epoch - 5ms/step
# Epoch 17/50
# 16/16 - 0s - loss: 0.4140 - val_loss: 0.5169 - 66ms/epoch - 4ms/step
# Epoch 18/50
# 16/16 - 0s - loss: 0.4135 - val_loss: 0.5148 - 75ms/epoch - 5ms/step
# Epoch 19/50
# 16/16 - 0s - loss: 0.4118 - val_loss: 0.5163 - 76ms/epoch - 5ms/step
# Epoch 20/50
# 16/16 - 0s - loss: 0.4123 - val_loss: 0.5159 - 76ms/epoch - 5ms/step
# Epoch 21/50
# 16/16 - 0s - loss: 0.4129 - val_loss: 0.5138 - 66ms/epoch - 4ms/step
# Epoch 22/50
# 16/16 - 0s - loss: 0.4122 - val_loss: 0.5159 - 65ms/epoch - 4ms/step
# Epoch 23/50
# 16/16 - 0s - loss: 0.4116 - val_loss: 0.5184 - 70ms/epoch - 4ms/step
# Epoch 24/50
# 16/16 - 0s - loss: 0.4132 - val_loss: 0.5144 - 78ms/epoch - 5ms/step
# Epoch 25/50
# 16/16 - 0s - loss: 0.4119 - val_loss: 0.5149 - 76ms/epoch - 5ms/step
# Epoch 26/50
# 16/16 - 0s - loss: 0.4114 - val_loss: 0.5180 - 66ms/epoch - 4ms/step
# Epoch 27/50
# 16/16 - 0s - loss: 0.4112 - val_loss: 0.5168 - 77ms/epoch - 5ms/step
# Epoch 28/50
# 16/16 - 0s - loss: 0.4119 - val_loss: 0.5161 - 67ms/epoch - 4ms/step
# Epoch 29/50
# 16/16 - 0s - loss: 0.4112 - val_loss: 0.5174 - 64ms/epoch - 4ms/step
# Epoch 30/50
# 16/16 - 0s - loss: 0.4121 - val_loss: 0.5192 - 65ms/epoch - 4ms/step
# Epoch 31/50
# 16/16 - 0s - loss: 0.4118 - val_loss: 0.5157 - 69ms/epoch - 4ms/step
# Epoch 32/50
# 16/16 - 0s - loss: 0.4112 - val_loss: 0.5167 - 79ms/epoch - 5ms/step
# Epoch 33/50
# 16/16 - 0s - loss: 0.4108 - val_loss: 0.5169 - 68ms/epoch - 4ms/step
# Epoch 34/50
# 16/16 - 0s - loss: 0.4109 - val_loss: 0.5178 - 78ms/epoch - 5ms/step
# Epoch 35/50
# 16/16 - 0s - loss: 0.4108 - val_loss: 0.5166 - 67ms/epoch - 4ms/step
# Epoch 36/50
# 16/16 - 0s - loss: 0.4112 - val_loss: 0.5167 - 69ms/epoch - 4ms/step
# Epoch 37/50
# 16/16 - 0s - loss: 0.4114 - val_loss: 0.5183 - 67ms/epoch - 4ms/step
# Epoch 38/50
# 16/16 - 0s - loss: 0.4102 - val_loss: 0.5166 - 82ms/epoch - 5ms/step
# Epoch 39/50
# 16/16 - 0s - loss: 0.4108 - val_loss: 0.5149 - 75ms/epoch - 5ms/step
# Epoch 40/50
# 16/16 - 0s - loss: 0.4114 - val_loss: 0.5129 - 64ms/epoch - 4ms/step
# Epoch 41/50
# 16/16 - 0s - loss: 0.4130 - val_loss: 0.5173 - 64ms/epoch - 4ms/step
# Epoch 42/50
# 16/16 - 0s - loss: 0.4106 - val_loss: 0.5191 - 64ms/epoch - 4ms/step
# Epoch 43/50
# 16/16 - 0s - loss: 0.4104 - val_loss: 0.5169 - 64ms/epoch - 4ms/step
# Epoch 44/50
# 16/16 - 0s - loss: 0.4107 - val_loss: 0.5152 - 65ms/epoch - 4ms/step
# Epoch 45/50
# 16/16 - 0s - loss: 0.4122 - val_loss: 0.5148 - 69ms/epoch - 4ms/step
# Epoch 46/50
# 16/16 - 0s - loss: 0.4108 - val_loss: 0.5169 - 64ms/epoch - 4ms/step
# Epoch 47/50
# 16/16 - 0s - loss: 0.4109 - val_loss: 0.5181 - 74ms/epoch - 5ms/step
# Epoch 48/50
# 16/16 - 0s - loss: 0.4107 - val_loss: 0.5148 - 68ms/epoch - 4ms/step
# Epoch 49/50
# 16/16 - 0s - loss: 0.4109 - val_loss: 0.5170 - 64ms/epoch - 4ms/step
# Epoch 50/50
# 16/16 - 0s - loss: 0.4112 - val_loss: 0.5166 - 68ms/epoch - 4ms/step
# 10/10 [==============================] - 0s 2ms/step
# Epoch 1/50
# 16/16 - 0s - loss: 0.4119 - val_loss: 0.5195 - 122ms/epoch - 8ms/step
# Epoch 2/50
# 16/16 - 0s - loss: 0.4098 - val_loss: 0.5180 - 67ms/epoch - 4ms/step
# Epoch 3/50
# 16/16 - 0s - loss: 0.4101 - val_loss: 0.5177 - 69ms/epoch - 4ms/step
# Epoch 4/50
# 16/16 - 0s - loss: 0.4103 - val_loss: 0.5140 - 68ms/epoch - 4ms/step
# Epoch 5/50
# 16/16 - 0s - loss: 0.4098 - val_loss: 0.5158 - 64ms/epoch - 4ms/step
# Epoch 6/50
# 16/16 - 0s - loss: 0.4098 - val_loss: 0.5185 - 69ms/epoch - 4ms/step
# Epoch 7/50
# 16/16 - 0s - loss: 0.4113 - val_loss: 0.5167 - 67ms/epoch - 4ms/step
# Epoch 8/50
# 16/16 - 0s - loss: 0.4102 - val_loss: 0.5197 - 70ms/epoch - 4ms/step
# Epoch 9/50
# 16/16 - 0s - loss: 0.4103 - val_loss: 0.5177 - 73ms/epoch - 5ms/step
# Epoch 10/50
# 16/16 - 0s - loss: 0.4104 - val_loss: 0.5155 - 87ms/epoch - 5ms/step
# Epoch 11/50
# 16/16 - 0s - loss: 0.4095 - val_loss: 0.5179 - 69ms/epoch - 4ms/step
# Epoch 12/50
# 16/16 - 0s - loss: 0.4099 - val_loss: 0.5161 - 74ms/epoch - 5ms/step
# Epoch 13/50
# 16/16 - 0s - loss: 0.4091 - val_loss: 0.5163 - 74ms/epoch - 5ms/step
# Epoch 14/50
# 16/16 - 0s - loss: 0.4105 - val_loss: 0.5183 - 74ms/epoch - 5ms/step
# Epoch 15/50
# 16/16 - 0s - loss: 0.4101 - val_loss: 0.5140 - 73ms/epoch - 5ms/step
# Epoch 16/50
# 16/16 - 0s - loss: 0.4096 - val_loss: 0.5144 - 80ms/epoch - 5ms/step
# Epoch 17/50
# 16/16 - 0s - loss: 0.4087 - val_loss: 0.5182 - 72ms/epoch - 5ms/step
# Epoch 18/50
# 16/16 - 0s - loss: 0.4096 - val_loss: 0.5178 - 69ms/epoch - 4ms/step
# Epoch 19/50
# 16/16 - 0s - loss: 0.4115 - val_loss: 0.5207 - 69ms/epoch - 4ms/step
# Epoch 20/50
# 16/16 - 0s - loss: 0.4096 - val_loss: 0.5164 - 79ms/epoch - 5ms/step
# Epoch 21/50
# 16/16 - 0s - loss: 0.4097 - val_loss: 0.5176 - 66ms/epoch - 4ms/step
# Epoch 22/50
# 16/16 - 0s - loss: 0.4098 - val_loss: 0.5176 - 66ms/epoch - 4ms/step
# Epoch 23/50
# 16/16 - 0s - loss: 0.4091 - val_loss: 0.5184 - 82ms/epoch - 5ms/step
# Epoch 24/50
# 16/16 - 0s - loss: 0.4089 - val_loss: 0.5163 - 69ms/epoch - 4ms/step
# Epoch 25/50
# 16/16 - 0s - loss: 0.4094 - val_loss: 0.5168 - 67ms/epoch - 4ms/step
# Epoch 26/50
# 16/16 - 0s - loss: 0.4104 - val_loss: 0.5191 - 76ms/epoch - 5ms/step
# Epoch 27/50
# 16/16 - 0s - loss: 0.4094 - val_loss: 0.5158 - 70ms/epoch - 4ms/step
# Epoch 28/50
# 16/16 - 0s - loss: 0.4088 - val_loss: 0.5156 - 79ms/epoch - 5ms/step
# Epoch 29/50
# 16/16 - 0s - loss: 0.4089 - val_loss: 0.5190 - 78ms/epoch - 5ms/step
# Epoch 30/50
# 16/16 - 0s - loss: 0.4096 - val_loss: 0.5192 - 72ms/epoch - 5ms/step
# Epoch 31/50
# 16/16 - 0s - loss: 0.4083 - val_loss: 0.5174 - 77ms/epoch - 5ms/step
# Epoch 32/50
# 16/16 - 0s - loss: 0.4084 - val_loss: 0.5160 - 76ms/epoch - 5ms/step
# Epoch 33/50
# 16/16 - 0s - loss: 0.4089 - val_loss: 0.5165 - 67ms/epoch - 4ms/step
# Epoch 34/50
# 16/16 - 0s - loss: 0.4091 - val_loss: 0.5166 - 76ms/epoch - 5ms/step
# Epoch 35/50
# 16/16 - 0s - loss: 0.4081 - val_loss: 0.5193 - 68ms/epoch - 4ms/step
# Epoch 36/50
# 16/16 - 0s - loss: 0.4087 - val_loss: 0.5171 - 68ms/epoch - 4ms/step
# Epoch 37/50
# 16/16 - 0s - loss: 0.4087 - val_loss: 0.5191 - 93ms/epoch - 6ms/step
# Epoch 38/50
# 16/16 - 0s - loss: 0.4081 - val_loss: 0.5163 - 77ms/epoch - 5ms/step
# Epoch 39/50
# 16/16 - 0s - loss: 0.4082 - val_loss: 0.5167 - 66ms/epoch - 4ms/step
# Epoch 40/50
# 16/16 - 0s - loss: 0.4077 - val_loss: 0.5195 - 91ms/epoch - 6ms/step
# Epoch 41/50
# 16/16 - 0s - loss: 0.4084 - val_loss: 0.5176 - 77ms/epoch - 5ms/step
# Epoch 42/50
# 16/16 - 0s - loss: 0.4090 - val_loss: 0.5207 - 71ms/epoch - 4ms/step
# Epoch 43/50
# 16/16 - 0s - loss: 0.4077 - val_loss: 0.5171 - 73ms/epoch - 5ms/step
# Epoch 44/50
# 16/16 - 0s - loss: 0.4110 - val_loss: 0.5137 - 69ms/epoch - 4ms/step
# Epoch 45/50
# 16/16 - 0s - loss: 0.4083 - val_loss: 0.5191 - 82ms/epoch - 5ms/step
# Epoch 46/50
# 16/16 - 0s - loss: 0.4085 - val_loss: 0.5181 - 76ms/epoch - 5ms/step
# Epoch 47/50
# 16/16 - 0s - loss: 0.4081 - val_loss: 0.5187 - 66ms/epoch - 4ms/step
# Epoch 48/50
# 16/16 - 0s - loss: 0.4080 - val_loss: 0.5168 - 71ms/epoch - 4ms/step
# Epoch 49/50
# 16/16 - 0s - loss: 0.4079 - val_loss: 0.5180 - 77ms/epoch - 5ms/step
# Epoch 50/50
# 16/16 - 0s - loss: 0.4082 - val_loss: 0.5179 - 76ms/epoch - 5ms/step
# 10/10 [==============================] - 0s 3ms/step
# Epoch 1/50
# 16/16 - 0s - loss: 0.4074 - val_loss: 0.5190 - 162ms/epoch - 10ms/step
# Epoch 2/50
# 16/16 - 0s - loss: 0.4074 - val_loss: 0.5173 - 101ms/epoch - 6ms/step
# Epoch 3/50
# 16/16 - 0s - loss: 0.4078 - val_loss: 0.5190 - 87ms/epoch - 5ms/step
# Epoch 4/50
# 16/16 - 0s - loss: 0.4081 - val_loss: 0.5185 - 93ms/epoch - 6ms/step
# Epoch 5/50
# 16/16 - 0s - loss: 0.4074 - val_loss: 0.5179 - 142ms/epoch - 9ms/step
# Epoch 6/50
# 16/16 - 0s - loss: 0.4074 - val_loss: 0.5161 - 100ms/epoch - 6ms/step
# Epoch 7/50
# 16/16 - 0s - loss: 0.4091 - val_loss: 0.5217 - 90ms/epoch - 6ms/step
# Epoch 8/50
# 16/16 - 0s - loss: 0.4079 - val_loss: 0.5175 - 91ms/epoch - 6ms/step
# Epoch 9/50
# 16/16 - 0s - loss: 0.4074 - val_loss: 0.5183 - 104ms/epoch - 6ms/step
# Epoch 10/50
# 16/16 - 0s - loss: 0.4066 - val_loss: 0.5179 - 96ms/epoch - 6ms/step
# Epoch 11/50
# 16/16 - 0s - loss: 0.4089 - val_loss: 0.5160 - 93ms/epoch - 6ms/step
# Epoch 12/50
# 16/16 - 0s - loss: 0.4063 - val_loss: 0.5212 - 120ms/epoch - 7ms/step
# Epoch 13/50
# 16/16 - 0s - loss: 0.4072 - val_loss: 0.5194 - 101ms/epoch - 6ms/step
# Epoch 14/50
# 16/16 - 0s - loss: 0.4071 - val_loss: 0.5205 - 95ms/epoch - 6ms/step
# Epoch 15/50
# 16/16 - 0s - loss: 0.4066 - val_loss: 0.5180 - 153ms/epoch - 10ms/step
# Epoch 16/50
# 16/16 - 0s - loss: 0.4073 - val_loss: 0.5196 - 95ms/epoch - 6ms/step
# Epoch 17/50
# 16/16 - 0s - loss: 0.4066 - val_loss: 0.5181 - 97ms/epoch - 6ms/step
# Epoch 18/50
# 16/16 - 0s - loss: 0.4068 - val_loss: 0.5177 - 101ms/epoch - 6ms/step
# Epoch 19/50
# 16/16 - 0s - loss: 0.4064 - val_loss: 0.5178 - 104ms/epoch - 6ms/step
# Epoch 20/50
# 16/16 - 0s - loss: 0.4065 - val_loss: 0.5170 - 103ms/epoch - 6ms/step
# Epoch 21/50
# 16/16 - 0s - loss: 0.4063 - val_loss: 0.5198 - 96ms/epoch - 6ms/step
# Epoch 22/50
# 16/16 - 0s - loss: 0.4067 - val_loss: 0.5167 - 101ms/epoch - 6ms/step
# Epoch 23/50
# 16/16 - 0s - loss: 0.4070 - val_loss: 0.5210 - 103ms/epoch - 6ms/step
# Epoch 24/50
# 16/16 - 0s - loss: 0.4066 - val_loss: 0.5180 - 143ms/epoch - 9ms/step
# Epoch 25/50
# 16/16 - 0s - loss: 0.4059 - val_loss: 0.5175 - 107ms/epoch - 7ms/step
# Epoch 26/50
# 16/16 - 0s - loss: 0.4072 - val_loss: 0.5166 - 99ms/epoch - 6ms/step
# Epoch 27/50
# 16/16 - 0s - loss: 0.4057 - val_loss: 0.5186 - 96ms/epoch - 6ms/step
# Epoch 28/50
# 16/16 - 0s - loss: 0.4064 - val_loss: 0.5184 - 99ms/epoch - 6ms/step
# Epoch 29/50
# 16/16 - 0s - loss: 0.4060 - val_loss: 0.5210 - 98ms/epoch - 6ms/step
# Epoch 30/50
# 16/16 - 0s - loss: 0.4058 - val_loss: 0.5181 - 97ms/epoch - 6ms/step
# Epoch 31/50
# 16/16 - 0s - loss: 0.4060 - val_loss: 0.5175 - 106ms/epoch - 7ms/step
# Epoch 32/50
# 16/16 - 0s - loss: 0.4057 - val_loss: 0.5184 - 98ms/epoch - 6ms/step
# Epoch 33/50
# 16/16 - 0s - loss: 0.4067 - val_loss: 0.5180 - 103ms/epoch - 6ms/step
# Epoch 34/50
# 16/16 - 0s - loss: 0.4066 - val_loss: 0.5172 - 111ms/epoch - 7ms/step
# Epoch 35/50
# 16/16 - 0s - loss: 0.4054 - val_loss: 0.5187 - 101ms/epoch - 6ms/step
# Epoch 36/50
# 16/16 - 0s - loss: 0.4065 - val_loss: 0.5197 - 80ms/epoch - 5ms/step
# Epoch 37/50
# 16/16 - 0s - loss: 0.4065 - val_loss: 0.5200 - 68ms/epoch - 4ms/step
# Epoch 38/50
# 16/16 - 0s - loss: 0.4091 - val_loss: 0.5163 - 70ms/epoch - 4ms/step
# Epoch 39/50
# 16/16 - 0s - loss: 0.4058 - val_loss: 0.5204 - 67ms/epoch - 4ms/step
# Epoch 40/50
# 16/16 - 0s - loss: 0.4061 - val_loss: 0.5194 - 67ms/epoch - 4ms/step
# Epoch 41/50
# 16/16 - 0s - loss: 0.4052 - val_loss: 0.5181 - 75ms/epoch - 5ms/step
# Epoch 42/50
# 16/16 - 0s - loss: 0.4055 - val_loss: 0.5170 - 77ms/epoch - 5ms/step
# Epoch 43/50
# 16/16 - 0s - loss: 0.4059 - val_loss: 0.5157 - 71ms/epoch - 4ms/step
# Epoch 44/50
# 16/16 - 0s - loss: 0.4057 - val_loss: 0.5191 - 75ms/epoch - 5ms/step
# Epoch 45/50
# 16/16 - 0s - loss: 0.4054 - val_loss: 0.5191 - 75ms/epoch - 5ms/step
# Epoch 46/50
# 16/16 - 0s - loss: 0.4051 - val_loss: 0.5177 - 74ms/epoch - 5ms/step
# Epoch 47/50
# 16/16 - 0s - loss: 0.4046 - val_loss: 0.5162 - 77ms/epoch - 5ms/step
# Epoch 48/50
# 16/16 - 0s - loss: 0.4054 - val_loss: 0.5174 - 68ms/epoch - 4ms/step
# Epoch 49/50
# 16/16 - 0s - loss: 0.4050 - val_loss: 0.5158 - 203ms/epoch - 13ms/step
# Epoch 50/50
# 16/16 - 0s - loss: 0.4046 - val_loss: 0.5174 - 184ms/epoch - 12ms/step
# 10/10 [==============================] - 0s 2ms/step
# Epoch 1/50
# 16/16 - 0s - loss: 0.4052 - val_loss: 0.5187 - 119ms/epoch - 7ms/step
# Epoch 2/50
# 16/16 - 0s - loss: 0.4052 - val_loss: 0.5165 - 74ms/epoch - 5ms/step
# Epoch 3/50
# 16/16 - 0s - loss: 0.4054 - val_loss: 0.5193 - 72ms/epoch - 4ms/step
# Epoch 4/50
# 16/16 - 0s - loss: 0.4055 - val_loss: 0.5181 - 76ms/epoch - 5ms/step
# Epoch 5/50
# 16/16 - 0s - loss: 0.4051 - val_loss: 0.5177 - 76ms/epoch - 5ms/step
# Epoch 6/50
# 16/16 - 0s - loss: 0.4052 - val_loss: 0.5179 - 75ms/epoch - 5ms/step
# Epoch 7/50
# 16/16 - 0s - loss: 0.4064 - val_loss: 0.5203 - 68ms/epoch - 4ms/step
# Epoch 8/50
# 16/16 - 0s - loss: 0.4040 - val_loss: 0.5159 - 66ms/epoch - 4ms/step
# Epoch 9/50
# 16/16 - 0s - loss: 0.4045 - val_loss: 0.5159 - 65ms/epoch - 4ms/step
# Epoch 10/50
# 16/16 - 0s - loss: 0.4042 - val_loss: 0.5182 - 76ms/epoch - 5ms/step
# Epoch 11/50
# 16/16 - 0s - loss: 0.4046 - val_loss: 0.5165 - 79ms/epoch - 5ms/step
# Epoch 12/50
# 16/16 - 0s - loss: 0.4047 - val_loss: 0.5185 - 75ms/epoch - 5ms/step
# Epoch 13/50
# 16/16 - 0s - loss: 0.4048 - val_loss: 0.5160 - 66ms/epoch - 4ms/step
# Epoch 14/50
# 16/16 - 0s - loss: 0.4043 - val_loss: 0.5190 - 75ms/epoch - 5ms/step
# Epoch 15/50
# 16/16 - 0s - loss: 0.4051 - val_loss: 0.5192 - 83ms/epoch - 5ms/step
# Epoch 16/50
# 16/16 - 0s - loss: 0.4044 - val_loss: 0.5200 - 64ms/epoch - 4ms/step
# Epoch 17/50
# 16/16 - 0s - loss: 0.4042 - val_loss: 0.5178 - 65ms/epoch - 4ms/step
# Epoch 18/50
# 16/16 - 0s - loss: 0.4051 - val_loss: 0.5177 - 93ms/epoch - 6ms/step
# Epoch 19/50
# 16/16 - 0s - loss: 0.4039 - val_loss: 0.5191 - 68ms/epoch - 4ms/step
# Epoch 20/50
# 16/16 - 0s - loss: 0.4041 - val_loss: 0.5156 - 79ms/epoch - 5ms/step
# Epoch 21/50
# 16/16 - 0s - loss: 0.4038 - val_loss: 0.5182 - 78ms/epoch - 5ms/step
# Epoch 22/50
# 16/16 - 0s - loss: 0.4042 - val_loss: 0.5175 - 66ms/epoch - 4ms/step
# Epoch 23/50
# 16/16 - 0s - loss: 0.4053 - val_loss: 0.5188 - 67ms/epoch - 4ms/step
# Epoch 24/50
# 16/16 - 0s - loss: 0.4054 - val_loss: 0.5155 - 75ms/epoch - 5ms/step
# Epoch 25/50
# 16/16 - 0s - loss: 0.4042 - val_loss: 0.5171 - 67ms/epoch - 4ms/step
# Epoch 26/50
# 16/16 - 0s - loss: 0.4042 - val_loss: 0.5156 - 64ms/epoch - 4ms/step
# Epoch 27/50
# 16/16 - 0s - loss: 0.4035 - val_loss: 0.5196 - 74ms/epoch - 5ms/step
# Epoch 28/50
# 16/16 - 0s - loss: 0.4033 - val_loss: 0.5187 - 65ms/epoch - 4ms/step
# Epoch 29/50
# 16/16 - 0s - loss: 0.4043 - val_loss: 0.5157 - 75ms/epoch - 5ms/step
# Epoch 30/50
# 16/16 - 0s - loss: 0.4031 - val_loss: 0.5185 - 74ms/epoch - 5ms/step
# Epoch 31/50
# 16/16 - 0s - loss: 0.4039 - val_loss: 0.5185 - 76ms/epoch - 5ms/step
# Epoch 32/50
# 16/16 - 0s - loss: 0.4028 - val_loss: 0.5181 - 72ms/epoch - 5ms/step
# Epoch 33/50
# 16/16 - 0s - loss: 0.4031 - val_loss: 0.5180 - 76ms/epoch - 5ms/step
# Epoch 34/50
# 16/16 - 0s - loss: 0.4047 - val_loss: 0.5161 - 67ms/epoch - 4ms/step
# Epoch 35/50
# 16/16 - 0s - loss: 0.4042 - val_loss: 0.5200 - 66ms/epoch - 4ms/step
# Epoch 36/50
# 16/16 - 0s - loss: 0.4026 - val_loss: 0.5197 - 81ms/epoch - 5ms/step
# Epoch 37/50
# 16/16 - 0s - loss: 0.4036 - val_loss: 0.5159 - 76ms/epoch - 5ms/step
# Epoch 38/50
# 16/16 - 0s - loss: 0.4035 - val_loss: 0.5145 - 64ms/epoch - 4ms/step
# Epoch 39/50
# 16/16 - 0s - loss: 0.4036 - val_loss: 0.5148 - 64ms/epoch - 4ms/step
# Epoch 40/50
# 16/16 - 0s - loss: 0.4019 - val_loss: 0.5193 - 67ms/epoch - 4ms/step
# Epoch 41/50
# 16/16 - 0s - loss: 0.4032 - val_loss: 0.5209 - 68ms/epoch - 4ms/step
# Epoch 42/50
# 16/16 - 0s - loss: 0.4030 - val_loss: 0.5166 - 76ms/epoch - 5ms/step
# Epoch 43/50
# 16/16 - 0s - loss: 0.4030 - val_loss: 0.5186 - 77ms/epoch - 5ms/step
# Epoch 44/50
# 16/16 - 0s - loss: 0.4030 - val_loss: 0.5160 - 66ms/epoch - 4ms/step
# Epoch 45/50
# 16/16 - 0s - loss: 0.4029 - val_loss: 0.5163 - 72ms/epoch - 5ms/step
# Epoch 46/50
# 16/16 - 0s - loss: 0.4034 - val_loss: 0.5197 - 75ms/epoch - 5ms/step
# Epoch 47/50
# 16/16 - 0s - loss: 0.4037 - val_loss: 0.5174 - 76ms/epoch - 5ms/step
# Epoch 48/50
# 16/16 - 0s - loss: 0.4023 - val_loss: 0.5157 - 77ms/epoch - 5ms/step
# Epoch 49/50
# 16/16 - 0s - loss: 0.4029 - val_loss: 0.5151 - 65ms/epoch - 4ms/step
# Epoch 50/50
# 16/16 - 0s - loss: 0.4024 - val_loss: 0.5165 - 66ms/epoch - 4ms/step
# 10/10 [==============================] - 0s 2ms/step
# Epoch 1/50
# 16/16 - 0s - loss: 0.4021 - val_loss: 0.5150 - 118ms/epoch - 7ms/step
# Epoch 2/50
# 16/16 - 0s - loss: 0.4018 - val_loss: 0.5175 - 76ms/epoch - 5ms/step
# Epoch 3/50
# 16/16 - 0s - loss: 0.4030 - val_loss: 0.5179 - 67ms/epoch - 4ms/step
# Epoch 4/50
# 16/16 - 0s - loss: 0.4021 - val_loss: 0.5143 - 69ms/epoch - 4ms/step
# Epoch 5/50
# 16/16 - 0s - loss: 0.4019 - val_loss: 0.5152 - 66ms/epoch - 4ms/step
# Epoch 6/50
# 16/16 - 0s - loss: 0.4025 - val_loss: 0.5178 - 67ms/epoch - 4ms/step
# Epoch 7/50
# 16/16 - 0s - loss: 0.4021 - val_loss: 0.5177 - 64ms/epoch - 4ms/step
# Epoch 8/50
# 16/16 - 0s - loss: 0.4017 - val_loss: 0.5160 - 64ms/epoch - 4ms/step
# Epoch 9/50
# 16/16 - 0s - loss: 0.4015 - val_loss: 0.5151 - 77ms/epoch - 5ms/step
# Epoch 10/50
# 16/16 - 0s - loss: 0.4019 - val_loss: 0.5162 - 67ms/epoch - 4ms/step
# Epoch 11/50
# 16/16 - 0s - loss: 0.4025 - val_loss: 0.5163 - 78ms/epoch - 5ms/step
# Epoch 12/50
# 16/16 - 0s - loss: 0.4016 - val_loss: 0.5160 - 67ms/epoch - 4ms/step
# Epoch 13/50
# 16/16 - 0s - loss: 0.4026 - val_loss: 0.5176 - 71ms/epoch - 4ms/step
# Epoch 14/50
# 16/16 - 0s - loss: 0.4020 - val_loss: 0.5157 - 66ms/epoch - 4ms/step
# Epoch 15/50
# 16/16 - 0s - loss: 0.4010 - val_loss: 0.5168 - 67ms/epoch - 4ms/step
# Epoch 16/50
# 16/16 - 0s - loss: 0.4015 - val_loss: 0.5179 - 85ms/epoch - 5ms/step
# Epoch 17/50
# 16/16 - 0s - loss: 0.4013 - val_loss: 0.5146 - 68ms/epoch - 4ms/step
# Epoch 18/50
# 16/16 - 0s - loss: 0.4014 - val_loss: 0.5159 - 66ms/epoch - 4ms/step
# Epoch 19/50
# 16/16 - 0s - loss: 0.4024 - val_loss: 0.5173 - 73ms/epoch - 5ms/step
# Epoch 20/50
# 16/16 - 0s - loss: 0.4009 - val_loss: 0.5166 - 69ms/epoch - 4ms/step
# Epoch 21/50
# 16/16 - 0s - loss: 0.4020 - val_loss: 0.5182 - 67ms/epoch - 4ms/step
# Epoch 22/50
# 16/16 - 0s - loss: 0.4006 - val_loss: 0.5141 - 66ms/epoch - 4ms/step
# Epoch 23/50
# 16/16 - 0s - loss: 0.4007 - val_loss: 0.5170 - 68ms/epoch - 4ms/step
# Epoch 24/50
# 16/16 - 0s - loss: 0.4002 - val_loss: 0.5160 - 64ms/epoch - 4ms/step
# Epoch 25/50
# 16/16 - 0s - loss: 0.4001 - val_loss: 0.5148 - 64ms/epoch - 4ms/step
# Epoch 26/50
# 16/16 - 0s - loss: 0.4002 - val_loss: 0.5154 - 63ms/epoch - 4ms/step
# Epoch 27/50
# 16/16 - 0s - loss: 0.4003 - val_loss: 0.5153 - 73ms/epoch - 5ms/step
# Epoch 28/50
# 16/16 - 0s - loss: 0.4010 - val_loss: 0.5141 - 66ms/epoch - 4ms/step
# Epoch 29/50
# 16/16 - 0s - loss: 0.4002 - val_loss: 0.5149 - 64ms/epoch - 4ms/step
# Epoch 30/50
# 16/16 - 0s - loss: 0.4004 - val_loss: 0.5147 - 66ms/epoch - 4ms/step
# Epoch 31/50
# 16/16 - 0s - loss: 0.4006 - val_loss: 0.5148 - 77ms/epoch - 5ms/step
# Epoch 32/50
# 16/16 - 0s - loss: 0.4004 - val_loss: 0.5159 - 66ms/epoch - 4ms/step
# Epoch 33/50
# 16/16 - 0s - loss: 0.4008 - val_loss: 0.5148 - 66ms/epoch - 4ms/step
# Epoch 34/50
# 16/16 - 0s - loss: 0.3999 - val_loss: 0.5159 - 72ms/epoch - 4ms/step
# Epoch 35/50
# 16/16 - 0s - loss: 0.4000 - val_loss: 0.5185 - 76ms/epoch - 5ms/step
# Epoch 36/50
# 16/16 - 0s - loss: 0.3995 - val_loss: 0.5152 - 75ms/epoch - 5ms/step
# Epoch 37/50
# 16/16 - 0s - loss: 0.3991 - val_loss: 0.5158 - 79ms/epoch - 5ms/step
# Epoch 38/50
# 16/16 - 0s - loss: 0.3993 - val_loss: 0.5171 - 67ms/epoch - 4ms/step
# Epoch 39/50
# 16/16 - 0s - loss: 0.3993 - val_loss: 0.5171 - 65ms/epoch - 4ms/step
# Epoch 40/50
# 16/16 - 0s - loss: 0.4004 - val_loss: 0.5132 - 73ms/epoch - 5ms/step
# Epoch 41/50
# 16/16 - 0s - loss: 0.3987 - val_loss: 0.5160 - 65ms/epoch - 4ms/step
# Epoch 42/50
# 16/16 - 0s - loss: 0.3998 - val_loss: 0.5162 - 76ms/epoch - 5ms/step
# Epoch 43/50
# 16/16 - 0s - loss: 0.3990 - val_loss: 0.5160 - 76ms/epoch - 5ms/step
# Epoch 44/50
# 16/16 - 0s - loss: 0.3988 - val_loss: 0.5148 - 96ms/epoch - 6ms/step
# Epoch 45/50
# 16/16 - 0s - loss: 0.3996 - val_loss: 0.5126 - 104ms/epoch - 6ms/step
# Epoch 46/50
# 16/16 - 0s - loss: 0.3988 - val_loss: 0.5160 - 95ms/epoch - 6ms/step
# Epoch 47/50
# 16/16 - 0s - loss: 0.3986 - val_loss: 0.5159 - 106ms/epoch - 7ms/step
# Epoch 48/50
# 16/16 - 0s - loss: 0.4000 - val_loss: 0.5164 - 94ms/epoch - 6ms/step
# Epoch 49/50
# 16/16 - 0s - loss: 0.3983 - val_loss: 0.5154 - 97ms/epoch - 6ms/step
# Epoch 50/50
# 16/16 - 0s - loss: 0.3995 - val_loss: 0.5139 - 102ms/epoch - 6ms/step
# 10/10 [==============================] - 0s 2ms/step
# Epoch 1/50
# 16/16 - 0s - loss: 0.3983 - val_loss: 0.5163 - 157ms/epoch - 10ms/step
# Epoch 2/50
# 16/16 - 0s - loss: 0.3983 - val_loss: 0.5156 - 98ms/epoch - 6ms/step
# Epoch 3/50
# 16/16 - 0s - loss: 0.3992 - val_loss: 0.5146 - 103ms/epoch - 6ms/step
# Epoch 4/50
# 16/16 - 0s - loss: 0.3983 - val_loss: 0.5172 - 98ms/epoch - 6ms/step
# Epoch 5/50
# 16/16 - 0s - loss: 0.3987 - val_loss: 0.5162 - 95ms/epoch - 6ms/step
# Epoch 6/50
# 16/16 - 0s - loss: 0.3987 - val_loss: 0.5159 - 96ms/epoch - 6ms/step
# Epoch 7/50
# 16/16 - 0s - loss: 0.3979 - val_loss: 0.5123 - 91ms/epoch - 6ms/step
# Epoch 8/50
# 16/16 - 0s - loss: 0.3981 - val_loss: 0.5148 - 99ms/epoch - 6ms/step
# Epoch 9/50
# 16/16 - 0s - loss: 0.3976 - val_loss: 0.5160 - 97ms/epoch - 6ms/step
# Epoch 10/50
# 16/16 - 0s - loss: 0.3992 - val_loss: 0.5182 - 112ms/epoch - 7ms/step
# Epoch 11/50
# 16/16 - 0s - loss: 0.3974 - val_loss: 0.5158 - 96ms/epoch - 6ms/step
# Epoch 12/50
# 16/16 - 0s - loss: 0.3983 - val_loss: 0.5141 - 94ms/epoch - 6ms/step
# Epoch 13/50
# 16/16 - 0s - loss: 0.3975 - val_loss: 0.5135 - 97ms/epoch - 6ms/step
# Epoch 14/50
# 16/16 - 0s - loss: 0.3978 - val_loss: 0.5139 - 103ms/epoch - 6ms/step
# Epoch 15/50
# 16/16 - 0s - loss: 0.3978 - val_loss: 0.5146 - 85ms/epoch - 5ms/step
# Epoch 16/50
# 16/16 - 0s - loss: 0.3977 - val_loss: 0.5148 - 69ms/epoch - 4ms/step
# Epoch 17/50
# 16/16 - 0s - loss: 0.3990 - val_loss: 0.5169 - 77ms/epoch - 5ms/step
# Epoch 18/50
# 16/16 - 0s - loss: 0.3970 - val_loss: 0.5145 - 73ms/epoch - 5ms/step
# Epoch 19/50
# 16/16 - 0s - loss: 0.3973 - val_loss: 0.5168 - 76ms/epoch - 5ms/step
# Epoch 20/50
# 16/16 - 0s - loss: 0.3975 - val_loss: 0.5145 - 71ms/epoch - 4ms/step
# Epoch 21/50
# 16/16 - 0s - loss: 0.3973 - val_loss: 0.5133 - 67ms/epoch - 4ms/step
# Epoch 22/50
# 16/16 - 0s - loss: 0.4003 - val_loss: 0.5158 - 87ms/epoch - 5ms/step
# Epoch 23/50
# 16/16 - 0s - loss: 0.3980 - val_loss: 0.5130 - 66ms/epoch - 4ms/step
# Epoch 24/50
# 16/16 - 0s - loss: 0.3976 - val_loss: 0.5139 - 66ms/epoch - 4ms/step
# Epoch 25/50
# 16/16 - 0s - loss: 0.3972 - val_loss: 0.5146 - 83ms/epoch - 5ms/step
# Epoch 26/50
# 16/16 - 0s - loss: 0.3973 - val_loss: 0.5140 - 66ms/epoch - 4ms/step
# Epoch 27/50
# 16/16 - 0s - loss: 0.3971 - val_loss: 0.5157 - 67ms/epoch - 4ms/step
# Epoch 28/50
# 16/16 - 0s - loss: 0.3970 - val_loss: 0.5149 - 66ms/epoch - 4ms/step
# Epoch 29/50
# 16/16 - 0s - loss: 0.3976 - val_loss: 0.5130 - 69ms/epoch - 4ms/step
# Epoch 30/50
# 16/16 - 0s - loss: 0.3971 - val_loss: 0.5141 - 76ms/epoch - 5ms/step
# Epoch 31/50
# 16/16 - 0s - loss: 0.3983 - val_loss: 0.5134 - 77ms/epoch - 5ms/step
# Epoch 32/50
# 16/16 - 0s - loss: 0.3976 - val_loss: 0.5134 - 69ms/epoch - 4ms/step
# Epoch 33/50
# 16/16 - 0s - loss: 0.3964 - val_loss: 0.5136 - 65ms/epoch - 4ms/step
# Epoch 34/50
# 16/16 - 0s - loss: 0.3971 - val_loss: 0.5135 - 78ms/epoch - 5ms/step
# Epoch 35/50
# 16/16 - 0s - loss: 0.3958 - val_loss: 0.5131 - 73ms/epoch - 5ms/step
# Epoch 36/50
# 16/16 - 0s - loss: 0.3965 - val_loss: 0.5139 - 74ms/epoch - 5ms/step
# Epoch 37/50
# 16/16 - 0s - loss: 0.3976 - val_loss: 0.5139 - 73ms/epoch - 5ms/step
# Epoch 38/50
# 16/16 - 0s - loss: 0.3968 - val_loss: 0.5108 - 75ms/epoch - 5ms/step
# Epoch 39/50
# 16/16 - 0s - loss: 0.3964 - val_loss: 0.5151 - 66ms/epoch - 4ms/step
# Epoch 40/50
# 16/16 - 0s - loss: 0.3960 - val_loss: 0.5155 - 69ms/epoch - 4ms/step
# Epoch 41/50
# 16/16 - 0s - loss: 0.3966 - val_loss: 0.5130 - 71ms/epoch - 4ms/step
# Epoch 42/50
# 16/16 - 0s - loss: 0.3973 - val_loss: 0.5123 - 66ms/epoch - 4ms/step
# Epoch 43/50
# 16/16 - 0s - loss: 0.3958 - val_loss: 0.5139 - 79ms/epoch - 5ms/step
# Epoch 44/50
# 16/16 - 0s - loss: 0.3961 - val_loss: 0.5137 - 77ms/epoch - 5ms/step
# Epoch 45/50
# 16/16 - 0s - loss: 0.3962 - val_loss: 0.5116 - 67ms/epoch - 4ms/step
# Epoch 46/50
# 16/16 - 0s - loss: 0.3959 - val_loss: 0.5108 - 77ms/epoch - 5ms/step
# Epoch 47/50
# 16/16 - 0s - loss: 0.3950 - val_loss: 0.5138 - 66ms/epoch - 4ms/step
# Epoch 48/50
# 16/16 - 0s - loss: 0.3962 - val_loss: 0.5138 - 80ms/epoch - 5ms/step
# Epoch 49/50
# 16/16 - 0s - loss: 0.3960 - val_loss: 0.5131 - 80ms/epoch - 5ms/step
# Epoch 50/50
# 16/16 - 0s - loss: 0.3955 - val_loss: 0.5113 - 76ms/epoch - 5ms/step
# 10/10 [==============================] - 0s 2ms/step
# Epoch 1/50
# 16/16 - 0s - loss: 0.3955 - val_loss: 0.5132 - 118ms/epoch - 7ms/step
# Epoch 2/50
# 16/16 - 0s - loss: 0.3956 - val_loss: 0.5137 - 78ms/epoch - 5ms/step
# Epoch 3/50
# 16/16 - 0s - loss: 0.3953 - val_loss: 0.5118 - 69ms/epoch - 4ms/step
# Epoch 4/50
# 16/16 - 0s - loss: 0.3967 - val_loss: 0.5109 - 75ms/epoch - 5ms/step
# Epoch 5/50
# 16/16 - 0s - loss: 0.3951 - val_loss: 0.5135 - 69ms/epoch - 4ms/step
# Epoch 6/50
# 16/16 - 0s - loss: 0.3956 - val_loss: 0.5118 - 69ms/epoch - 4ms/step
# Epoch 7/50
# 16/16 - 0s - loss: 0.3954 - val_loss: 0.5131 - 76ms/epoch - 5ms/step
# Epoch 8/50
# 16/16 - 0s - loss: 0.3958 - val_loss: 0.5111 - 67ms/epoch - 4ms/step
# Epoch 9/50
# ...
# Epoch 7/50
# 16/16 - 0s - loss: 0.3717 - val_loss: 0.4981 - 80ms/epoch - 5ms/step
# Epoch 8/50
# 16/16 - 0s - loss: 0.3711 - val_loss: 0.5004 - 73ms/epoch - 5ms/step
# Epoch 9/50
# 16/16 - 0s - loss: 0.3721 - val_loss: 0.5013 - 77ms/epoch - 5ms/step
# Epoch 10/50
# 16/16 - 0s - loss: 0.3713 - val_loss: 0.4974 - 92ms/epoch - 6ms/step
# Epoch 11/50
# 16/16 - 0s - loss: 0.3709 - val_loss: 0.4987 - 79ms/epoch - 5ms/step
# Epoch 12/50
# 16/16 - 0s - loss: 0.3710 - val_loss: 0.4999 - 71ms/epoch - 4ms/step
# Epoch 13/50
# 16/16 - 0s - loss: 0.3704 - val_loss: 0.4977 - 66ms/epoch - 4ms/step
# Epoch 14/50
# 16/16 - 0s - loss: 0.3726 - val_loss: 0.4998 - 71ms/epoch - 4ms/step
# Epoch 15/50
# 16/16 - 0s - loss: 0.3714 - val_loss: 0.4989 - 78ms/epoch - 5ms/step
# Epoch 16/50
# 16/16 - 0s - loss: 0.3723 - val_loss: 0.4997 - 86ms/epoch - 5ms/step
# Epoch 17/50
# 16/16 - 0s - loss: 0.3713 - val_loss: 0.4957 - 80ms/epoch - 5ms/step
# Epoch 18/50
# 16/16 - 0s - loss: 0.3709 - val_loss: 0.4997 - 74ms/epoch - 5ms/step
# Epoch 19/50
# 16/16 - 0s - loss: 0.3707 - val_loss: 0.5010 - 71ms/epoch - 4ms/step
# Epoch 20/50
# 16/16 - 0s - loss: 0.3730 - val_loss: 0.4970 - 79ms/epoch - 5ms/step
# Epoch 21/50
# 16/16 - 0s - loss: 0.3719 - val_loss: 0.4995 - 75ms/epoch - 5ms/step
# Epoch 22/50
# 16/16 - 0s - loss: 0.3718 - val_loss: 0.4981 - 70ms/epoch - 4ms/step
# Epoch 23/50
# 16/16 - 0s - loss: 0.3713 - val_loss: 0.4989 - 88ms/epoch - 5ms/step
# Epoch 24/50
# 16/16 - 0s - loss: 0.3713 - val_loss: 0.5018 - 80ms/epoch - 5ms/step
# Epoch 25/50
# 16/16 - 0s - loss: 0.3704 - val_loss: 0.4985 - 70ms/epoch - 4ms/step
# Epoch 26/50
# 16/16 - 0s - loss: 0.3708 - val_loss: 0.4980 - 82ms/epoch - 5ms/step
# Epoch 27/50
# 16/16 - 0s - loss: 0.3711 - val_loss: 0.4970 - 72ms/epoch - 4ms/step
# Epoch 28/50
# 16/16 - 0s - loss: 0.3707 - val_loss: 0.4988 - 70ms/epoch - 4ms/step
# Epoch 29/50
# 16/16 - 0s - loss: 0.3710 - val_loss: 0.5003 - 74ms/epoch - 5ms/step
# Epoch 30/50
# 16/16 - 0s - loss: 0.3707 - val_loss: 0.4991 - 67ms/epoch - 4ms/step
# Epoch 31/50
# 16/16 - 0s - loss: 0.3707 - val_loss: 0.4983 - 73ms/epoch - 5ms/step
# Epoch 32/50
# 16/16 - 0s - loss: 0.3711 - val_loss: 0.4989 - 72ms/epoch - 4ms/step
# Epoch 33/50
# 16/16 - 0s - loss: 0.3702 - val_loss: 0.4985 - 82ms/epoch - 5ms/step
# Epoch 34/50
# 16/16 - 0s - loss: 0.3705 - val_loss: 0.5011 - 83ms/epoch - 5ms/step
# Epoch 35/50
# 16/16 - 0s - loss: 0.3718 - val_loss: 0.4973 - 87ms/epoch - 5ms/step
# Epoch 36/50
# 16/16 - 0s - loss: 0.3710 - val_loss: 0.4986 - 82ms/epoch - 5ms/step
# Epoch 37/50
# 16/16 - 0s - loss: 0.3713 - val_loss: 0.4997 - 76ms/epoch - 5ms/step
# Epoch 38/50
# 16/16 - 0s - loss: 0.3707 - val_loss: 0.4995 - 75ms/epoch - 5ms/step
# Epoch 39/50
# 16/16 - 0s - loss: 0.3705 - val_loss: 0.4983 - 74ms/epoch - 5ms/step
# Epoch 40/50
# 16/16 - 0s - loss: 0.3706 - val_loss: 0.4983 - 80ms/epoch - 5ms/step
# Epoch 41/50
# 16/16 - 0s - loss: 0.3702 - val_loss: 0.4973 - 79ms/epoch - 5ms/step
# Epoch 42/50
# 16/16 - 0s - loss: 0.3710 - val_loss: 0.4965 - 72ms/epoch - 4ms/step
# Epoch 43/50
# 16/16 - 0s - loss: 0.3710 - val_loss: 0.5012 - 72ms/epoch - 5ms/step
# Epoch 44/50
# 16/16 - 0s - loss: 0.3705 - val_loss: 0.4994 - 82ms/epoch - 5ms/step
# Epoch 45/50
# 16/16 - 0s - loss: 0.3714 - val_loss: 0.4977 - 78ms/epoch - 5ms/step
# Epoch 46/50
# 16/16 - 0s - loss: 0.3703 - val_loss: 0.4998 - 73ms/epoch - 5ms/step
# Epoch 47/50
# 16/16 - 0s - loss: 0.3732 - val_loss: 0.4970 - 72ms/epoch - 5ms/step
# Epoch 48/50
# 16/16 - 0s - loss: 0.3709 - val_loss: 0.5030 - 99ms/epoch - 6ms/step
# Epoch 49/50
# 16/16 - 0s - loss: 0.3710 - val_loss: 0.4975 - 72ms/epoch - 4ms/step
# Epoch 50/50
# 16/16 - 0s - loss: 0.3705 - val_loss: 0.4983 - 73ms/epoch - 5ms/step
# 10/10 [==============================] - 0s 2ms/step
# Epoch 1/50
# 16/16 - 0s - loss: 0.3720 - val_loss: 0.5005 - 121ms/epoch - 8ms/step
# Epoch 2/50
# 16/16 - 0s - loss: 0.3710 - val_loss: 0.4970 - 80ms/epoch - 5ms/step
# Epoch 3/50
# 16/16 - 0s - loss: 0.3718 - val_loss: 0.5017 - 81ms/epoch - 5ms/step
# Epoch 4/50
# 16/16 - 0s - loss: 0.3714 - val_loss: 0.4977 - 74ms/epoch - 5ms/step
# Epoch 5/50
# 16/16 - 0s - loss: 0.3712 - val_loss: 0.4973 - 80ms/epoch - 5ms/step
# Epoch 6/50
# 16/16 - 0s - loss: 0.3712 - val_loss: 0.4987 - 72ms/epoch - 5ms/step
# Epoch 7/50
# 16/16 - 0s - loss: 0.3712 - val_loss: 0.5004 - 75ms/epoch - 5ms/step
# Epoch 8/50
# 16/16 - 0s - loss: 0.3704 - val_loss: 0.4991 - 86ms/epoch - 5ms/step
# Epoch 9/50
# 16/16 - 0s - loss: 0.3705 - val_loss: 0.4974 - 80ms/epoch - 5ms/step
# Epoch 10/50
# 16/16 - 0s - loss: 0.3706 - val_loss: 0.5003 - 81ms/epoch - 5ms/step
# Epoch 11/50
# 16/16 - 0s - loss: 0.3708 - val_loss: 0.5008 - 87ms/epoch - 5ms/step
# Epoch 12/50
# 16/16 - 0s - loss: 0.3716 - val_loss: 0.4978 - 87ms/epoch - 5ms/step
# Epoch 13/50
# 16/16 - 0s - loss: 0.3713 - val_loss: 0.4995 - 73ms/epoch - 5ms/step
# Epoch 14/50
# 16/16 - 0s - loss: 0.3707 - val_loss: 0.4982 - 83ms/epoch - 5ms/step
# Epoch 15/50
# 16/16 - 0s - loss: 0.3706 - val_loss: 0.4975 - 84ms/epoch - 5ms/step
# Epoch 16/50
# 16/16 - 0s - loss: 0.3702 - val_loss: 0.5021 - 93ms/epoch - 6ms/step
# Epoch 17/50
# 16/16 - 0s - loss: 0.3727 - val_loss: 0.4986 - 114ms/epoch - 7ms/step
# Epoch 18/50
# 16/16 - 0s - loss: 0.3707 - val_loss: 0.4999 - 111ms/epoch - 7ms/step
# Epoch 19/50
# 16/16 - 0s - loss: 0.3711 - val_loss: 0.5000 - 111ms/epoch - 7ms/step
# Epoch 20/50
# 16/16 - 0s - loss: 0.3703 - val_loss: 0.5000 - 104ms/epoch - 6ms/step
# Epoch 21/50
# 16/16 - 0s - loss: 0.3721 - val_loss: 0.4971 - 104ms/epoch - 6ms/step
# Epoch 22/50
# 16/16 - 0s - loss: 0.3704 - val_loss: 0.5020 - 109ms/epoch - 7ms/step
# Epoch 23/50
# 16/16 - 0s - loss: 0.3704 - val_loss: 0.4982 - 100ms/epoch - 6ms/step
# Epoch 24/50
# 16/16 - 0s - loss: 0.3714 - val_loss: 0.4961 - 105ms/epoch - 7ms/step
# Epoch 25/50
# 16/16 - 0s - loss: 0.3715 - val_loss: 0.5004 - 115ms/epoch - 7ms/step
# Epoch 26/50
# 16/16 - 0s - loss: 0.3707 - val_loss: 0.5030 - 108ms/epoch - 7ms/step
# Epoch 27/50
# 16/16 - 0s - loss: 0.3702 - val_loss: 0.4992 - 100ms/epoch - 6ms/step
# Epoch 28/50
# 16/16 - 0s - loss: 0.3709 - val_loss: 0.4989 - 108ms/epoch - 7ms/step
# Epoch 29/50
# 16/16 - 0s - loss: 0.3699 - val_loss: 0.5019 - 108ms/epoch - 7ms/step
# Epoch 30/50
# 16/16 - 0s - loss: 0.3706 - val_loss: 0.5014 - 116ms/epoch - 7ms/step
# Epoch 31/50
# 16/16 - 0s - loss: 0.3700 - val_loss: 0.4965 - 109ms/epoch - 7ms/step
# Epoch 32/50
# 16/16 - 0s - loss: 0.3717 - val_loss: 0.4982 - 106ms/epoch - 7ms/step
# Epoch 33/50
# 16/16 - 0s - loss: 0.3710 - val_loss: 0.4977 - 106ms/epoch - 7ms/step
# Epoch 34/50
# 16/16 - 0s - loss: 0.3708 - val_loss: 0.5022 - 107ms/epoch - 7ms/step
# Epoch 35/50
# 16/16 - 0s - loss: 0.3705 - val_loss: 0.4973 - 101ms/epoch - 6ms/step
# Epoch 36/50
# 16/16 - 0s - loss: 0.3710 - val_loss: 0.5029 - 99ms/epoch - 6ms/step
# Epoch 37/50
# 16/16 - 0s - loss: 0.3709 - val_loss: 0.4987 - 98ms/epoch - 6ms/step
# Epoch 38/50
# 16/16 - 0s - loss: 0.3703 - val_loss: 0.4986 - 101ms/epoch - 6ms/step
# Epoch 39/50
# 16/16 - 0s - loss: 0.3700 - val_loss: 0.5021 - 95ms/epoch - 6ms/step
# Epoch 40/50
# 16/16 - 0s - loss: 0.3711 - val_loss: 0.4988 - 103ms/epoch - 6ms/step
# Epoch 41/50
# 16/16 - 0s - loss: 0.3702 - val_loss: 0.4982 - 141ms/epoch - 9ms/step
# Epoch 42/50
# 16/16 - 0s - loss: 0.3718 - val_loss: 0.4985 - 106ms/epoch - 7ms/step
# Epoch 43/50
# 16/16 - 0s - loss: 0.3697 - val_loss: 0.5018 - 103ms/epoch - 6ms/step
# Epoch 44/50
# 16/16 - 0s - loss: 0.3701 - val_loss: 0.5000 - 100ms/epoch - 6ms/step
# Epoch 45/50
# 16/16 - 0s - loss: 0.3725 - val_loss: 0.4992 - 146ms/epoch - 9ms/step
# Epoch 46/50
# 16/16 - 0s - loss: 0.3733 - val_loss: 0.4957 - 108ms/epoch - 7ms/step
# Epoch 47/50
# 16/16 - 0s - loss: 0.3705 - val_loss: 0.5024 - 118ms/epoch - 7ms/step
# Epoch 48/50
# 16/16 - 0s - loss: 0.3702 - val_loss: 0.4987 - 100ms/epoch - 6ms/step
# Epoch 49/50
# 16/16 - 0s - loss: 0.3703 - val_loss: 0.5008 - 102ms/epoch - 6ms/step
# Epoch 50/50
# 16/16 - 0s - loss: 0.3696 - val_loss: 0.5006 - 101ms/epoch - 6ms/step
# 10/10 [==============================] - 0s 3ms/step
# Epoch 1/50
# 16/16 - 0s - loss: 0.3723 - val_loss: 0.4988 - 164ms/epoch - 10ms/step
# Epoch 2/50
# 16/16 - 0s - loss: 0.3712 - val_loss: 0.5029 - 97ms/epoch - 6ms/step
# Epoch 3/50
# 16/16 - 0s - loss: 0.3695 - val_loss: 0.4977 - 98ms/epoch - 6ms/step
# Epoch 4/50
# 16/16 - 0s - loss: 0.3711 - val_loss: 0.4972 - 112ms/epoch - 7ms/step
# Epoch 5/50
# 16/16 - 0s - loss: 0.3715 - val_loss: 0.4990 - 100ms/epoch - 6ms/step
# Epoch 6/50
# 16/16 - 0s - loss: 0.3703 - val_loss: 0.5019 - 104ms/epoch - 7ms/step
# Epoch 7/50
# 16/16 - 0s - loss: 0.3713 - val_loss: 0.4986 - 99ms/epoch - 6ms/step
# Epoch 8/50
# 16/16 - 0s - loss: 0.3705 - val_loss: 0.4981 - 109ms/epoch - 7ms/step
# Epoch 9/50
# 16/16 - 0s - loss: 0.3702 - val_loss: 0.5002 - 100ms/epoch - 6ms/step
# Epoch 10/50
# 16/16 - 0s - loss: 0.3707 - val_loss: 0.4983 - 111ms/epoch - 7ms/step
# Epoch 11/50
# 16/16 - 0s - loss: 0.3715 - val_loss: 0.4982 - 81ms/epoch - 5ms/step
# Epoch 12/50
# 16/16 - 0s - loss: 0.3705 - val_loss: 0.5008 - 71ms/epoch - 4ms/step
# Epoch 13/50
# 16/16 - 0s - loss: 0.3714 - val_loss: 0.4986 - 78ms/epoch - 5ms/step
# Epoch 14/50
# 16/16 - 0s - loss: 0.3701 - val_loss: 0.4973 - 83ms/epoch - 5ms/step
# Epoch 15/50
# 16/16 - 0s - loss: 0.3705 - val_loss: 0.4999 - 84ms/epoch - 5ms/step
# Epoch 16/50
# 16/16 - 0s - loss: 0.3709 - val_loss: 0.4984 - 86ms/epoch - 5ms/step
# Epoch 17/50
# 16/16 - 0s - loss: 0.3700 - val_loss: 0.5026 - 81ms/epoch - 5ms/step
# Epoch 18/50
# 16/16 - 0s - loss: 0.3712 - val_loss: 0.4972 - 76ms/epoch - 5ms/step
# Epoch 19/50
# 16/16 - 0s - loss: 0.3696 - val_loss: 0.4987 - 75ms/epoch - 5ms/step
# Epoch 20/50
# 16/16 - 0s - loss: 0.3707 - val_loss: 0.4976 - 86ms/epoch - 5ms/step
# Epoch 21/50
# 16/16 - 0s - loss: 0.3698 - val_loss: 0.5012 - 84ms/epoch - 5ms/step
# Epoch 22/50
# 16/16 - 0s - loss: 0.3708 - val_loss: 0.4991 - 83ms/epoch - 5ms/step
# Epoch 23/50
# 16/16 - 0s - loss: 0.3693 - val_loss: 0.5000 - 73ms/epoch - 5ms/step
# Epoch 24/50
# 16/16 - 0s - loss: 0.3698 - val_loss: 0.4991 - 73ms/epoch - 5ms/step
# Epoch 25/50
# 16/16 - 0s - loss: 0.3711 - val_loss: 0.4969 - 71ms/epoch - 4ms/step
# Epoch 26/50
# 16/16 - 0s - loss: 0.3702 - val_loss: 0.5006 - 74ms/epoch - 5ms/step
# Epoch 27/50
# 16/16 - 0s - loss: 0.3718 - val_loss: 0.4951 - 86ms/epoch - 5ms/step
# Epoch 28/50
# 16/16 - 0s - loss: 0.3697 - val_loss: 0.4991 - 79ms/epoch - 5ms/step
# Epoch 29/50
# 16/16 - 0s - loss: 0.3699 - val_loss: 0.4966 - 79ms/epoch - 5ms/step
# Epoch 30/50
# 16/16 - 0s - loss: 0.3703 - val_loss: 0.4977 - 85ms/epoch - 5ms/step
# Epoch 31/50
# 16/16 - 0s - loss: 0.3692 - val_loss: 0.4960 - 78ms/epoch - 5ms/step
# Epoch 32/50
# 16/16 - 0s - loss: 0.3699 - val_loss: 0.4962 - 85ms/epoch - 5ms/step
# Epoch 33/50
# 16/16 - 0s - loss: 0.3710 - val_loss: 0.4982 - 72ms/epoch - 5ms/step
# Epoch 34/50
# 16/16 - 0s - loss: 0.3711 - val_loss: 0.4977 - 76ms/epoch - 5ms/step
# Epoch 35/50
# 16/16 - 0s - loss: 0.3699 - val_loss: 0.4963 - 72ms/epoch - 5ms/step
# Epoch 36/50
# 16/16 - 0s - loss: 0.3688 - val_loss: 0.4972 - 71ms/epoch - 4ms/step
# Epoch 37/50
# 16/16 - 0s - loss: 0.3707 - val_loss: 0.4990 - 84ms/epoch - 5ms/step
# Epoch 38/50
# 16/16 - 0s - loss: 0.3702 - val_loss: 0.5022 - 71ms/epoch - 4ms/step
# Epoch 39/50
# 16/16 - 0s - loss: 0.3694 - val_loss: 0.4985 - 88ms/epoch - 5ms/step
# Epoch 40/50
# 16/16 - 0s - loss: 0.3702 - val_loss: 0.4957 - 78ms/epoch - 5ms/step
# Epoch 41/50
# 16/16 - 0s - loss: 0.3696 - val_loss: 0.4997 - 81ms/epoch - 5ms/step
# Epoch 42/50
# 16/16 - 0s - loss: 0.3690 - val_loss: 0.4984 - 80ms/epoch - 5ms/step
# Epoch 43/50
# 16/16 - 0s - loss: 0.3706 - val_loss: 0.4998 - 82ms/epoch - 5ms/step
# Epoch 44/50
# 16/16 - 0s - loss: 0.3700 - val_loss: 0.4947 - 75ms/epoch - 5ms/step
# Epoch 45/50
# 16/16 - 0s - loss: 0.3698 - val_loss: 0.4972 - 75ms/epoch - 5ms/step
# Epoch 46/50
# 16/16 - 0s - loss: 0.3704 - val_loss: 0.4987 - 82ms/epoch - 5ms/step
# Epoch 47/50
# 16/16 - 0s - loss: 0.3699 - val_loss: 0.4958 - 82ms/epoch - 5ms/step
# Epoch 48/50
# 16/16 - 0s - loss: 0.3695 - val_loss: 0.4992 - 72ms/epoch - 4ms/step
# Epoch 49/50
# 16/16 - 0s - loss: 0.3694 - val_loss: 0.4991 - 73ms/epoch - 5ms/step
# Epoch 50/50
# 16/16 - 0s - loss: 0.3701 - val_loss: 0.4958 - 76ms/epoch - 5ms/step
# 10/10 [==============================] - 0s 2ms/step
# Epoch 1/50
# 16/16 - 0s - loss: 0.3684 - val_loss: 0.4971 - 128ms/epoch - 8ms/step
# Epoch 2/50
# 16/16 - 0s - loss: 0.3701 - val_loss: 0.4976 - 72ms/epoch - 4ms/step
# Epoch 3/50
# 16/16 - 0s - loss: 0.3694 - val_loss: 0.4972 - 94ms/epoch - 6ms/step
# Epoch 4/50
# 16/16 - 0s - loss: 0.3699 - val_loss: 0.4984 - 71ms/epoch - 4ms/step
# Epoch 5/50
# 16/16 - 0s - loss: 0.3692 - val_loss: 0.4974 - 71ms/epoch - 4ms/step
# Epoch 6/50
# 16/16 - 0s - loss: 0.3699 - val_loss: 0.4968 - 68ms/epoch - 4ms/step
# Epoch 7/50
# 16/16 - 0s - loss: 0.3691 - val_loss: 0.4958 - 77ms/epoch - 5ms/step
# Epoch 8/50
# 16/16 - 0s - loss: 0.3691 - val_loss: 0.4964 - 80ms/epoch - 5ms/step
# Epoch 9/50
# 16/16 - 0s - loss: 0.3695 - val_loss: 0.4984 - 77ms/epoch - 5ms/step
# Epoch 10/50
# 16/16 - 0s - loss: 0.3699 - val_loss: 0.4985 - 82ms/epoch - 5ms/step
# Epoch 11/50
# 16/16 - 0s - loss: 0.3713 - val_loss: 0.4945 - 72ms/epoch - 5ms/step
# Epoch 12/50
# 16/16 - 0s - loss: 0.3696 - val_loss: 0.4983 - 77ms/epoch - 5ms/step
# Epoch 13/50
# 16/16 - 0s - loss: 0.3695 - val_loss: 0.4990 - 73ms/epoch - 5ms/step
# Epoch 14/50
# 16/16 - 0s - loss: 0.3702 - val_loss: 0.4979 - 70ms/epoch - 4ms/step
# Epoch 15/50
# 16/16 - 0s - loss: 0.3695 - val_loss: 0.4961 - 70ms/epoch - 4ms/step
# Epoch 16/50
# 16/16 - 0s - loss: 0.3690 - val_loss: 0.4956 - 88ms/epoch - 6ms/step
# Epoch 17/50
# 16/16 - 0s - loss: 0.3694 - val_loss: 0.4987 - 85ms/epoch - 5ms/step
# Epoch 18/50
# 16/16 - 0s - loss: 0.3691 - val_loss: 0.4963 - 72ms/epoch - 4ms/step
# Epoch 19/50
# 16/16 - 0s - loss: 0.3690 - val_loss: 0.4983 - 74ms/epoch - 5ms/step
# Epoch 20/50
# 16/16 - 0s - loss: 0.3693 - val_loss: 0.4959 - 84ms/epoch - 5ms/step
# Epoch 21/50
# 16/16 - 0s - loss: 0.3707 - val_loss: 0.4980 - 80ms/epoch - 5ms/step
# Epoch 22/50
# 16/16 - 0s - loss: 0.3693 - val_loss: 0.4995 - 81ms/epoch - 5ms/step
# Epoch 23/50
# 16/16 - 0s - loss: 0.3698 - val_loss: 0.4948 - 71ms/epoch - 4ms/step
# Epoch 24/50
# 16/16 - 0s - loss: 0.3691 - val_loss: 0.4962 - 78ms/epoch - 5ms/step
# Epoch 25/50
# 16/16 - 0s - loss: 0.3712 - val_loss: 0.4998 - 73ms/epoch - 5ms/step
# Epoch 26/50
# 16/16 - 0s - loss: 0.3687 - val_loss: 0.4966 - 79ms/epoch - 5ms/step
# Epoch 27/50
# 16/16 - 0s - loss: 0.3696 - val_loss: 0.4995 - 72ms/epoch - 4ms/step
# Epoch 28/50
# 16/16 - 0s - loss: 0.3690 - val_loss: 0.4977 - 79ms/epoch - 5ms/step
# Epoch 29/50
# 16/16 - 0s - loss: 0.3695 - val_loss: 0.4982 - 84ms/epoch - 5ms/step
# Epoch 30/50
# 16/16 - 0s - loss: 0.3693 - val_loss: 0.4983 - 70ms/epoch - 4ms/step
# Epoch 31/50
# 16/16 - 0s - loss: 0.3686 - val_loss: 0.4980 - 82ms/epoch - 5ms/step
# Epoch 32/50
# 16/16 - 0s - loss: 0.3682 - val_loss: 0.4980 - 73ms/epoch - 5ms/step
# Epoch 33/50
# 16/16 - 0s - loss: 0.3687 - val_loss: 0.4984 - 72ms/epoch - 5ms/step
# Epoch 34/50
# 16/16 - 0s - loss: 0.3692 - val_loss: 0.4956 - 82ms/epoch - 5ms/step
# Epoch 35/50
# 16/16 - 0s - loss: 0.3694 - val_loss: 0.5006 - 76ms/epoch - 5ms/step
# Epoch 36/50
# 16/16 - 0s - loss: 0.3684 - val_loss: 0.4986 - 78ms/epoch - 5ms/step
# Epoch 37/50
# 16/16 - 0s - loss: 0.3688 - val_loss: 0.4975 - 80ms/epoch - 5ms/step
# Epoch 38/50
# 16/16 - 0s - loss: 0.3700 - val_loss: 0.4987 - 70ms/epoch - 4ms/step
# Epoch 39/50
# 16/16 - 0s - loss: 0.3696 - val_loss: 0.4969 - 79ms/epoch - 5ms/step
# Epoch 40/50
# 16/16 - 0s - loss: 0.3693 - val_loss: 0.5003 - 83ms/epoch - 5ms/step
# Epoch 41/50
# 16/16 - 0s - loss: 0.3690 - val_loss: 0.4993 - 87ms/epoch - 5ms/step
# Epoch 42/50
# 16/16 - 0s - loss: 0.3689 - val_loss: 0.4952 - 69ms/epoch - 4ms/step
# Epoch 43/50
# 16/16 - 0s - loss: 0.3706 - val_loss: 0.4961 - 72ms/epoch - 5ms/step
# Epoch 44/50
# 16/16 - 0s - loss: 0.3692 - val_loss: 0.4985 - 73ms/epoch - 5ms/step
# Epoch 45/50
# 16/16 - 0s - loss: 0.3697 - val_loss: 0.4988 - 72ms/epoch - 4ms/step
# Epoch 46/50
# 16/16 - 0s - loss: 0.3690 - val_loss: 0.4988 - 78ms/epoch - 5ms/step
# Epoch 47/50
# 16/16 - 0s - loss: 0.3687 - val_loss: 0.4956 - 75ms/epoch - 5ms/step
# Epoch 48/50
# 16/16 - 0s - loss: 0.3686 - val_loss: 0.4971 - 72ms/epoch - 4ms/step
# Epoch 49/50
# 16/16 - 0s - loss: 0.3688 - val_loss: 0.4965 - 80ms/epoch - 5ms/step
# Epoch 50/50
# 16/16 - 0s - loss: 0.3684 - val_loss: 0.4984 - 69ms/epoch - 4ms/step
# 10/10 [==============================] - 0s 2ms/step

# %% [markdown]
# ---
#
#
#
# ---

# %%
print(mse)  # list of 50 mean squared errors
len(mse)
# Out:
# [0.5840221917923275, 0.5899150604831233, 0.5896918557502793, 0.5894860955704747, 0.5887554117935347, 0.5899475079396561, 0.5870670666329406, 0.593686232297959, 0.5964081286064236, 0.5967044009119145, 0.598506243591532, 0.5993958390680247, 0.599948043103538, 0.6034113987841003, 0.6001399978137739, 0.6007501361646378, 0.601786459978713, 0.6040579439695565, 0.6036675839907416, 0.6038971626650422, 0.6028780928135107, 0.6062895429505759, 0.6006314092635295, 0.6019127843414874, 0.6026070836604764, 0.6005458375078272, 0.6081091891586686, 0.595605241491073, 0.5993072857799776, 0.5990654490325503, 0.5996760704841014, 0.5986788690972525, 0.6032886861145274, 0.6036951661946228, 0.604509943210015, 0.6007122066821581, 0.6000091950660997, 0.6009452572807844, 0.5975050974634841, 0.5999987654512314, 0.6025083342504657, 0.599097737750514, 0.5951170724856145, 0.59779445413191, 0.5964862236429846, 0.6011173232679448, 0.5997146751217992, 0.5987637449308417, 0.6008721217423092, 0.603806129394519]
# 50

# %% [markdown]
# ## 5. Report the mean and the standard deviation of the mean squared errors.

# %%
#  The  mean and the standard deviation of the mean squared errors
mean = sum(mse) / len(mse)
variance = sum([((x - mean) ** 2) for x in mse]) / len(mse)
std = variance ** 0.5

print(f'mean and the standard deviation of the mean squared errors is {mean:.5f} and {std:.5f} respectively.')
# Out:
# mean and the standard deviation of the mean squared errors is 0.59885 and 0.00509 respectively.

# %% [markdown]
# **The mean and mean squared error are small numbers compared to Part A.**
